# %% [markdown]
# Build a baseline model using the weather station data (this approach used all days in 2018 since the data was available).
#
#
# Then use the model to make predictions for the ENVI-met(micro-climate) data for that specific day and compare it to model predictions using weather station data also for the same day.

# %%
from google.colab import drive
drive.mount('/content/drive')

# %% [markdown]
# # 1. Import

# %%
import pandas as pd
import numpy as np
import pathlib
import pickle
import pathlib
import matplotlib.pyplot as plt
from matplotlib.pyplot import cm
from datetime import datetime
import seaborn as sns

# train-test split
from sklearn.model_selection import train_test_split

# %% [markdown]
# # 2. Load All Data

# %%
# LIMITED DATA
Bldg_Lim = []

# Read all building data and append to list
for path in pathlib.Path("./Data/microclimate_model/Combined/dataset3").iterdir():
        if path.is_file():
            current_file = pd.read_csv(path)
            current_file = current_file.drop(columns=['Unnamed: 0'])
            Bldg_Lim.append(current_file)

# BIG DATA
Bldg_Big = []

# Read all building data and append to list
for path in pathlib.Path("./Data/NN_big_data").iterdir():
        if path.is_file():
            current_file = pd.read_csv(path)
            current_file = current_file.drop(columns=['Unnamed: 0'])
            Bldg_Big.append(current_file)

# %% [markdown]
# ## 2.1 Preprocessing
#
# 1. Adding Month, Hour, and Minute to limited data
# 2. Removing hours out of ENVI-met accuracy range (after 9 pm) for limited data
# 3. Add CHWTON/SQFT to columns using condition area for each building taken from
#     https://fdm-apps.asu.edu/UFRM/FDS/FacilityData.aspx
# 4. Drop na rows in limited data (some data points from campus metabolism not available)
# 5. Drop 'index' column and rename 'rel humid' to 'rel hum' for big data
# 6. Calculate and create new column for absolute humidity using equations from https://www.hatchability.com/Vaisala.pdf which can be validated using https://planetcalc.com/2167/

# %%
## LIMITED DATA ##
# Create Month, Hour, and Minute column for all dataframes in list and drop unnecessary columns
for i in range(len(Bldg_Lim)):
    Bldg_Lim[i].Date_Time = pd.to_datetime(Bldg_Lim[i].Date_Time)
    Bldg_Lim[i]['Month'] = Bldg_Lim[i].Date_Time.dt.month
    Bldg_Lim[i]['Hour'] = Bldg_Lim[i].Date_Time.dt.hour
    Bldg_Lim[i]['Minute'] = Bldg_Lim[i].Date_Time.dt.minute
    Bldg_Lim[i]['Day'] = Bldg_Lim[i].Date_Time.dt.day
    Bldg_Lim[i] = Bldg_Lim[i].drop(columns = ['Date_Time'])

# Remove data after 9pm
for i in range(len(Bldg_Lim)):
    Bldg_Lim[i] = Bldg_Lim[i][(Bldg_Lim[i]['Hour'] <= 20) & (Bldg_Lim[i]['Hour'] > 0)]

# Add Column: CHWTON/Condition Area (SqFt) or ['CHWTON/SQFT']
cond_area = {'Noble Library':88658,'Biodesign B':132215,'Biodesign C':145410,
             'Biodesign A':133016,'Psychology':69864,'Goldwater':165237,'Schwada COB':99857,
             'ISTB 2':41404,'Bulldog Hall':68067,'ISTB 4':231646,'Psychology North':43034}
for i in range(len(Bldg_Lim)):
    if Bldg_Lim[i]['bldgname'][0] in cond_area:
        Bldg_Lim[i]['CHWTON/SQFT'] = Bldg_Lim[i]['CHWTON'] / cond_area[Bldg_Lim[i]['bldgname'][0]]

# Drop NA rows in data
for i in range(len(Bldg_Lim)):
  Bldg_Lim[i] = Bldg_Lim[i].dropna()
  Bldg_Lim[i] = Bldg_Lim[i].reset_index(drop=True)

## BIG DATA ##
# Rename 'Rel Humid' to 'Rel Hum' and drop 'index' column
for i in range(len(Bldg_Big)):
  Bldg_Big[i] = Bldg_Big[i].rename(columns = {'Rel Humid': 'Rel Hum'})
  Bldg_Big[i] = Bldg_Big[i].drop(columns=['index'])

# %%
# Check if NA in data
for i in range(len(Bldg_Lim)):
  null_data = Bldg_Lim[i][Bldg_Lim[i].isnull().any(axis=1)]
  print(null_data)
# Out:
# Empty DataFrame
# Columns: [bldgname, Date, Time, Air Temp, Rel Hum, KW, CHWTON, HTmmBTU, Month, Hour, Minute, Day, CHWTON/SQFT]
# Index: []
# Empty DataFrame
# Columns: [bldgname, Date, Time, Air Temp, Rel Hum, KW, CHWTON, HTmmBTU, Month, Hour, Minute, Day, CHWTON/SQFT]
# Index: []
# Empty DataFrame
# Columns: [bldgname, Date, Time, Air Temp, Rel Hum, KW, CHWTON, HTmmBTU, Month, Hour, Minute, Day, CHWTON/SQFT]
# Index: []
# Empty DataFrame
# Columns: [bldgname, Date, Time, Air Temp, Rel Hum, KW, CHWTON, HTmmBTU, Month, Hour, Minute, Day, CHWTON/SQFT]
# Index: []
# Empty DataFrame
# Columns: [bldgname, Date, Time, Air Temp, Rel Hum, KW, CHWTON, HTmmBTU, Month, Hour, Minute, Day, CHWTON/SQFT]
# Index: []
# Empty DataFrame
# Columns: [bldgname, Date, Time, Air Temp, Rel Hum, KW, CHWTON, HTmmBTU, Month, Hour, Minute, Day, CHWTON/SQFT]
# Index: []
# Empty DataFrame
# Columns: [bldgname, Date, Time, Air Temp, Rel Hum, KW, CHWTON, HTmmBTU, Month, Hour, Minute, Day, CHWTON/SQFT]
# Index: []
# Empty DataFrame
# Columns: [bldgname, Date, Time, Air Temp, Rel Hum, KW, CHWTON, HTmmBTU, Month, Hour, Minute, Day, CHWTON/SQFT]
# Index: []
# Empty DataFrame
# Columns: [bldgname, Date, Time, Air Temp, Rel Hum, KW, CHWTON, HTmmBTU, Month, Hour, Minute, Day, CHWTON/SQFT]
# Index: []
# Empty DataFrame
# Columns: [bldgname, Date, Time, Air Temp, Rel Hum, KW, CHWTON, HTmmBTU, Month, Hour, Minute, Day, CHWTON/SQFT]
# Index: []
# Empty DataFrame
# Columns: [bldgname, Date, Time, Air Temp, Rel Hum, KW, CHWTON, HTmmBTU, Month, Hour, Minute, Day, CHWTON/SQFT]
# Index: []

# %%
# Constants
P_c = 220640
T_c = 647.096
C_1 = -7.85951783
C_2 = 1.84408259
C_3 =  -11.7866497
C_4 = 22.6807411
C_5 = -15.9618719
C_6 = 1.80122502
C = 2.16679

# Convert Rel Hum to Abs Hum for Limited Data
for i in range(len(Bldg_Lim)):
    T_i = Bldg_Lim[i]['Air Temp']
    RH = Bldg_Lim[i]['Rel Hum']/100
    T = T_i + 273.15
    v = 1 - (T/T_c)
    x = (T_c/T)*((C_1*v) + (C_2*np.power(v, 1.5)) + (C_3*np.power(v, 3)) 
                 + (C_4*np.power(v, 3.5)) + (C_5*np.power(v, 4)) + (C_6*np.power(v, 7.5))) 
    P_ws = np.exp(x)*P_c
    P_w = P_ws*RH
    A = C*P_w*100/T
    Bldg_Lim[i]['Abs Hum'] = A

# Convert Rel Hum to Abs Hum for Big Data
for i in range(len(Bldg_Big)):
    T_i = Bldg_Big[i]['Air Temp']
    RH = Bldg_Big[i]['Rel Hum']/100
    T = T_i + 273.15
    v = 1 - (T/T_c)
    x = (T_c/T)*((C_1*v) + (C_2*np.power(v, 1.5)) + (C_3*np.power(v, 3)) 
                 + (C_4*np.power(v, 3.5)) + (C_5*np.power(v, 4)) + (C_6*np.power(v, 7.5))) 
    P_ws = np.exp(x)*P_c
    P_w = P_ws*RH
    A = C*P_w*100/T
    Bldg_Big[i]['Abs Hum'] = A

# %%
## Rearrange Columns

# For Limited Data
for i in range(len(Bldg_Lim)):
    cols = ['bldgname','Date','Time','Month','Day','Hour','Minute','Air Temp','Abs Hum', 'Rel Hum','KW','CHWTON','CHWTON/SQFT']
    Bldg_Lim[i] = Bldg_Lim[i][cols]

# For Big Data
for i in range(len(Bldg_Big)):
    cols = ['bldgname','Month','Day','Hour','Minute','Air Temp','Abs Hum', 'Rel Hum','KW','CHWTON','CHWTON/SQFT']
    Bldg_Big[i] = Bldg_Big[i][cols]

# %% [markdown]
# # 3. Single Building Analysis - Big Data

# %% [markdown]
# ## 3.1 Select Building

# %%
# Ask user to select building
for i in range(len(Bldg_Big)):
    print(i, Bldg_Big[i]['bldgname'][0])

bldgnum_B = int(input("Enter the number of the building from the list above: "))

Bldg_Big[bldgnum_B]
# Out:
# 0 Goldwater
# 1 Bulldog Hall
# 2 ISTB 2
# 3 Psychology North
# 4 Schwada COB
# 5 Biodesign C
# 6 Biodesign A
# 7 Psychology
# 8 Biodesign B
# 9 Noble Library
# 10 ISTB 4
# Enter the number of the building from the list above: 10
#       bldgname  Month  Day  Hour  Minute  Air Temp   Abs Hum  Rel Hum      KW  \
# 0       ISTB 4      1    1     0       0      11.0  4.028567    40.24  890.33
# 1       ISTB 4      1    1     0      15      11.0  4.028567    40.24  891.28
# 2       ISTB 4      1    1     0      30      10.0  4.042106    43.01  886.57
# 3       ISTB 4      1    1     0      45       9.0  4.056162    46.00  886.66
# 4       ISTB 4      1    1     1       0       9.0  4.056162    46.00  880.12
# ...        ...    ...  ...   ...     ...       ...       ...      ...     ...
# 34618   ISTB 4     12   31    22       0       6.0  6.773487    93.30  951.10
# 34619   ISTB 4     12   31    22      15       5.0  6.797015   100.00  952.58
# 34620   ISTB 4     12   31    22      30       5.0  6.797015   100.00  937.86
# 34621   ISTB 4     12   31    22      45       6.0  6.773487    93.30  941.16
# 34622   ISTB 4     12   31    23       0       6.0  6.773487    93.30  941.79
#
#        CHWTON  CHWTON/SQFT
# 0       70.48     0.000304
# 1       59.73     0.000258
# 2       64.01     0.000276
# 3       63.49     0.000274
# 4       68.87     0.000297
# ...       ...          ...
# 34618   69.14     0.000298
# 34619   70.95     0.000306
# 34620   68.62     0.000296
# 34621   70.36     0.000304
# 34622   73.25     0.000316
#
# [34623 rows x 11 columns]

# %% [markdown]
# ## 3.2 EDA

# %% [markdown]
# ### 3.2.1 Boxplots

# %%
# Show df columns to select for boxplot
x = Bldg_Big[bldgnum_B].columns
for i in range(len(x)):
    print(i, x[i])
# Get column name from user
colname = int(input("Enter the number of the following data columns to graph boxplot: "))
# Plot
print('\n',Bldg_Big[bldgnum_B]['bldgname'][0])
Bldg_Big[bldgnum_B].boxplot(by='Month', column=x[colname], grid = False, figsize = (8,8))

# %% [markdown]
# ### 3.2.2 Time Series

# %%
### will work on create Date and Time column for big data to visualize vs Limited Data

# %% [markdown]
# # 4. Single Building Analysis - Limited Data

# %% [markdown]
# ## 4.1 Select Building

# %%
# Ask user to select building
for i in range(len(Bldg_Lim)):
    print(i, Bldg_Lim[i]['bldgname'][0])

bldgnum_L = int(input("Enter the number of the building from the list above: "))

Bldg_Lim[bldgnum_L].head()
# Out:
# 0 Goldwater
# 1 Bulldog Hall
# 2 ISTB 2
# 3 Psychology North
# 4 Schwada COB
# 5 Biodesign C
# 6 Biodesign A
# 7 Psychology
# 8 Biodesign B
# 9 Noble Library
# 10 ISTB 4
# Enter the number of the building from the list above: 10
#   bldgname        Date   Time  Month  Day  Hour  Minute   Air Temp   Abs Hum  \
# 0   ISTB 4  2018-05-16  05:00      5   16     5       0  25.012220  4.430433
# 1   ISTB 4  2018-05-16  05:15      5   16     5      15  24.671093  4.864263
# 2   ISTB 4  2018-05-16  05:30      5   16     5      30  24.495274  4.786310
# 3   ISTB 4  2018-05-16  05:45      5   16     5      45  24.375078  4.778235
# 4   ISTB 4  2018-05-16  06:00      5   16     6       0  24.257700  4.793644
#
#      Rel Hum      KW  CHWTON  CHWTON/SQFT
# 0  19.218981  902.76  337.88     0.001459
# 1  21.510339  909.39  343.41     0.001482
# 2  21.376736  904.81  348.91     0.001506
# 3  21.486126  893.55  328.88     0.001420
# 4  21.699019  892.93  329.80     0.001424

# %% [markdown]
# ## 4.2 EDA

# %% [markdown]
# ### 4.2.1 Boxplots

# %%
# Show df columns to select for boxplot
x = Bldg_Lim[bldgnum_L].columns
for i in range(len(x)):
    print(i, x[i])
# Get column name from user
colname = int(input("Enter the number of the following data columns to graph boxplot: "))
# Plot
print('\n',Bldg_Lim[bldgnum_L]['bldgname'][0])
Bldg_Lim[bldgnum_L].boxplot(by='Hour', column=x[colname], grid = False, figsize = (8,8))

# %% [markdown]
# ### 4.2.2 Time Series

# %% [markdown]
# Month available:<br>
# May: 16, 23 <br>
# June: 7, 8, 20, 21, 25<br>
# August: 3<br>
# September: 11, 29<br>

# %%
import datetime
# Get month number for plotting
m_num = int(input("Enter month number: "))
# Convert to datetime to get month name
datetime_object = datetime.datetime.strptime(str(m_num), "%m")
m_name = datetime_object.strftime("%b")

# Plot only if entered month is in data
if m_num in Bldg_Lim[bldgnum_L]['Month'].unique():
    from datetime import datetime
    # Assign new df for chosen month
    plotdf = pd.DataFrame(Bldg_Lim[bldgnum_L][(Bldg_Lim[bldgnum_L]['Month'] == m_num)])
    # Show number of days found in chosen month
    x = plotdf['Date'].unique()
    print("\n", len(x), "day(s) found in", m_name, "\n")
    # Show all columns to select y-axis for plotting
    cols = plotdf.columns
    for i in range(len(cols)):
        print(i, cols[i])
    # Get y-axis for plotting
    y_ax = int(input('Enter y-axis from column list above: '))
    y_ax = cols[y_ax]
    for i in range(len(x)):
        datetime_object = datetime.strptime(x[i], '%Y-%m-%d')
        days = ['Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday', 'Saturday', 'Sunday']
        d = days[datetime_object.weekday()]
        plotdf1 = plotdf[(plotdf['Date']==x[i])]
        plotdf1.plot(x = 'Time', y = y_ax, grid = False, figsize = (8,8), title = x[i] + ' ' + d)
else:
    print("Month number not in data")

# %% [markdown]
# ### 4.2.3 Correlation Matrix

# %%
corr_pd = pd.DataFrame(Bldg_Lim[bldgnum_L][['Air Temp','Abs Hum', 'Rel Hum','KW', 'CHWTON/SQFT']])
corrMatrix = corr_pd.corr()
sns.heatmap(corrMatrix)

# %% [markdown]
# # 5. Train Models on both datasets

# %% [markdown]
# ## 5.1 Define Generalized Model Functions

# %%
#using single layer ANN. Model Parameters: hidden layer- 10 neurons, output layer- 1 neuron
from tensorflow.python.keras.models import Sequential
from tensorflow.python.keras.layers import Dense
from tensorflow.keras import initializers
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.layers import LeakyReLU
from tensorflow.keras.optimizers import SGD
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn import metrics
from tensorflow.keras import backend as K
def prepare_data(dataset):
    Y = dataset['CHWTON/SQFT']
    X = dataset[['Air Temp', 'Abs Hum']]
    Y= Y.values.reshape(-1, 1)
    # create scaler
    scaler1 = StandardScaler()
    X_scaled = scaler1.fit_transform(X)
    # #do for output variables
    scaler2 = StandardScaler()
    Y_scaled = scaler2.fit_transform(Y)
    X_scaled = np.asarray(X_scaled).astype('float32')
    Y_scaled = np.asarray(Y_scaled).astype('float32')
    return X_scaled,Y_scaled

def huber_loss(y_true, y_pred, clip_delta=1.0):
    error = y_true - y_pred
    cond  = tf.keras.backend.abs(error) < clip_delta
    squared_loss = 0.5 * tf.keras.backend.square(error)
    linear_loss  = clip_delta * (tf.keras.backend.abs(error) - 0.5 * clip_delta)
    return tf.where(cond, squared_loss, linear_loss)

'''
 ' Same as above but returns the mean loss.
'''
def huber_loss_mean(y_true, y_pred, clip_delta=1.0):
    return tf.keras.backend.mean(huber_loss(y_true, y_pred, clip_delta))

def define_model(activation_type, hidden_layers, loss, kernel_initializer='he_normal', bias_initializer='he_normal'):
    model = Sequential()
    if activation_type == 'leaky_relu':
        model.add(Dense(10, input_dim=2, kernel_initializer='he_normal'))
        model.add(LeakyReLU(alpha=0.1))
        for i in range(0,(hidden_layers-2)):
            model.add(Dense(8))
            model.add(LeakyReLU(alpha=0.1))
        model.add(Dense(16))
        model.add(Dense(1, activation='linear'))
    else:
        model.add(Dense(10, input_dim=2, kernel_initializer='he_normal', bias_initializer='he_normal', activation=activation_type))
        for i in range(0,(hidden_layers-2)):
            model.add(Dense(8, activation=activation_type))
        model.add(Dense(12, activation=activation_type))
        model.add(Dense(1, activation='linear'))
    model.compile(loss= loss, optimizer='adam', metrics = ['mse','mae'])
#     model.summary()
    return model
def fine_tune(model,loss):
    model.trainable = True
    fine_tune_at = 2
    for layer in model.layers[:fine_tune_at]:
      layer.trainable =  False
    model.compile(loss=loss, optimizer='adam', metrics = ['mse','mae'])
    return model
def plot_curve(history):
    plt.plot(history.history['loss'])
    plt.plot(history.history['val_loss'])
    plt.title('model loss')
    plt.ylabel('loss')
    plt.xlabel('epoch')
    plt.legend(['train', 'validation'], loc='upper left')
    plt.show()
def evaluate(model,X,Y):
    #evaluate on test dataset, add evaluation parameters
    Y_preds = model.predict(X)
    RMSE = np.sqrt(metrics.mean_squared_error(Y, Y_preds))
    R2_score = metrics.r2_score(Y, Y_preds)
#     test_loss = model.evaluate(X, Y)
    return RMSE, R2_score

# %% [markdown]
# ## 5.2 Prepare Data for feeding into training loop

# %%
# Limited Data
X_limited,Y_limited = prepare_data(Bldg_Lim[bldgnum_L])
X_limited_train, X_limited_test, Y_limited_train,Y_limited_test = train_test_split(X_limited,Y_limited , test_size=0.2, random_state=20)
X,Y = prepare_data(Bldg_Big[bldgnum_B])
X_train, X_test, Y_train,Y_test = train_test_split(X, Y, test_size=0.2, random_state=20)

# %%
# X_limited_test

# %% [markdown]
# ## 5.3 Hyperparameter Tuning experiments

# %%
# eval_func = []
# max_R2 = -inf
# for func in activation_functions:
#     eval_func_layers = []
#     for hl in no_hidden_layers:
#         eval_func_loss = []
#         for loss in loss_functions:
#             model = define_model(func,hl,loss)
#             history = model.fit(X_train, Y_train, batch_size=128, epochs=150,  validation_split=0.2, verbose=0)
#             RMSE, R2 = evaluate(base_model, X_test, Y_test)
#             RMSE_base_model, R2_base_model = evaluate(base_model, X_limited_test,Y_limited_test)
#             eval_func_loss.append(R2)
#         eval_func_layers.append(eval_func_loss)
#     eval_func.append(eval_func_layers)
# print(eval_func)   
# tab = pd.DataFrame(eval_func, activation_functions, no_hidden_layers_headings,loss_functions_headings)
# print(tab)

def tune_multiple_buildings():
    activation_functions = ['relu','elu','selu','leaky_relu','tanh']
    no_hidden_layers = [1,3,5]
    loss_functions = ['mean_squared_error','mean_absolute_error','mean_absolute_percentage_error',huber_loss,huber_loss_mean]
#     loss_functions_headings = ['mean_squared_error','mean_absolute_error','mean_absolute_percentage_error','huber_loss','huber_loss_mean']
    ### Create dataframe and add building names ###
    rf_optimal_model = pd.DataFrame(columns = {"bldgname", "R2_score_bigdata_best","R2_score_limiteddata_best", 'Activation Function','No of hidden layers', 'Loss function' })
    for i in range(len(Bldg_Lim)):
        rf_optimal_model = rf_optimal_model.append({'bldgname': Bldg_Lim[i]['bldgname'].unique()[0]}, ignore_index=True)
    rf_optimal_model.fillna(5)
    ### Train over all hyperparameters over all buildings ###
    for i in range(len(Bldg_Lim)):
        max = 0
        # drop na values if in dataframe
        if (Bldg_Lim[i].isnull().values.any() == True):
            Bldg_Lim[i] = Bldg_Lim[i].dropna()
        building_name = Bldg_Lim[i]['bldgname'][0] 
        print("Find parameters for "+ building_name)
        optimal_hyperparameters=[]
        # Limited Data
        X_limited,Y_limited = prepare_data(Bldg_Lim[i])
        X_limited_train, X_limited_test, Y_limited_train,Y_limited_test = train_test_split(X_limited,Y_limited , test_size=0.1, random_state=20)
        #Big Data
        X,Y = prepare_data(Bldg_Big[i])
        X_train, X_test, Y_train,Y_test = train_test_split(X, Y, test_size=0.2, random_state=20)
        for func in activation_functions:
            for hl in no_hidden_layers:
                for loss in loss_functions:
                    print("Results for hyperparameters:Activation Fn: "+ func+ " #hidden_layers: "+ str(hl) + " loss function: "+ str(loss))
                    model = define_model(func,hl,loss)
                    history = model.fit(X_train, Y_train, batch_size=128, epochs=150,  validation_split=0.2, verbose=0)
                    RMSE, R2 = evaluate(model, X_test, Y_test)
                    RMSE_base_model, R2_base_model = evaluate(model, X_limited_test,Y_limited_test)
                    print(R2_base_model)
                    if(R2_base_model>max):
                        max = R2_base_model
                        print("Updated hyperparameters for building: "+ building_name +"max_R2:"+str(max)+": Activation Fn: "+ str(func)+ " #hidden_layers: "+ str(hl) + " loss function: "+ str(loss))
                        rf_optimal_model["R2_score_bigdata_best"][i]=R2
                        rf_optimal_model["R2_score_limiteddata_best"][i]=R2_base_model
                        rf_optimal_model["Activation Function"][i]=func
                        rf_optimal_model["No of hidden layers"][i]=hl
                        rf_optimal_model["Loss function"][i]=loss
    rf_optimal_model = rf_optimal_model[["bldgname", "R2_score_bigdata_best","R2_score_limiteddata_best", 'Activation Function','No of hidden layers', 'Loss function']]
    return rf_optimal_model
optimal_model_buildings = tune_multiple_buildings()
display(optimal_model_buildings)
# Out:
# Find parameters for Goldwater
# Results for hyperparameters:Activation Fn: relu #hidden_layers: 1 loss function: mean_squared_error
# 2021-10-24 02:49:05.106345: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcuda.so.1
# 2021-10-24 02:49:05.166240: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:982] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-10-24 02:49:05.166967: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1716] Found device 0 with properties:
# pciBusID: 0000:03:00.0 name: GeForce MX130 computeCapability: 5.0
# coreClock: 1.189GHz coreCount: 3 deviceMemorySize: 1.96GiB deviceMemoryBandwidth: 37.33GiB/s
# 2021-10-24 02:49:05.167099: W tensorflow/stream_executor/platform/default/dso_loader.cc:59] Could not load dynamic library 'libcudart.so.10.1'; dlerror: libcudart.so.10.1: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /home/biswas/testing/devel/lib:/home/biswas/catkin_ws/devel/lib:/opt/ros/melodic/lib
# 2021-10-24 02:49:05.167230: W tensorflow/stream_executor/platform/default/dso_loader.cc:59] Could not load dynamic library 'libcublas.so.10'; dlerror: libcublas.so.10: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /home/biswas/testing/devel/lib:/home/biswas/catkin_ws/devel/lib:/opt/ros/melodic/lib
# 2021-10-24 02:49:05.167341: W tensorflow/stream_executor/platform/default/dso_loader.cc:59] Could not load dynamic library 'libcufft.so.10'; dlerror: libcufft.so.10: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /home/biswas/testing/devel/lib:/home/biswas/catkin_ws/devel/lib:/opt/ros/melodic/lib
# 2021-10-24 02:49:05.167492: W tensorflow/stream_executor/platform/default/dso_loader.cc:59] Could not load dynamic library 'libcurand.so.10'; dlerror: libcurand.so.10: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /home/biswas/testing/devel/lib:/home/biswas/catkin_ws/devel/lib:/opt/ros/melodic/lib
# 2021-10-24 02:49:05.167682: W tensorflow/stream_executor/platform/default/dso_loader.cc:59] Could not load dynamic library 'libcusolver.so.10'; dlerror: libcusolver.so.10: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /home/biswas/testing/devel/lib:/home/biswas/catkin_ws/devel/lib:/opt/ros/melodic/lib
# 2021-10-24 02:49:05.167791: W tensorflow/stream_executor/platform/default/dso_loader.cc:59] Could not load dynamic library 'libcusparse.so.10'; dlerror: libcusparse.so.10: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /home/biswas/testing/devel/lib:/home/biswas/catkin_ws/devel/lib:/opt/ros/melodic/lib
# 2021-10-24 02:49:05.167897: W tensorflow/stream_executor/platform/default/dso_loader.cc:59] Could not load dynamic library 'libcudnn.so.7'; dlerror: libcudnn.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /home/biswas/testing/devel/lib:/home/biswas/catkin_ws/devel/lib:/opt/ros/melodic/lib
# 2021-10-24 02:49:05.167908: W tensorflow/core/common_runtime/gpu/gpu_device.cc:1753] Cannot dlopen some GPU libraries. Please make sure the missing libraries mentioned above are installed properly if you would like to use GPU. Follow the guide at https://www.tensorflow.org/install/gpu for how to download and setup the required libraries for your platform.
# Skipping registering GPU devices...
# 2021-10-24 02:49:05.168295: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN)to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2021-10-24 02:49:05.184768: I tensorflow/core/platform/profile_utils/cpu_utils.cc:104] CPU Frequency: 2099940000 Hz
# 2021-10-24 02:49:05.187395: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x8d9b9c0 initialized for platform Host (this does not guarantee that XLA will be used). Devices:
# 2021-10-24 02:49:05.187541: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): Host, Default Version
# 2021-10-24 02:49:05.195083: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1257] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2021-10-24 02:49:05.195129: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1263]
# 0.9235961936494737
# Updated hyperparameters for building: Goldwatermax_R2:0.9235961936494737: Activation Fn: relu #hidden_layers: 1 loss function: mean_squared_error
# Results for hyperparameters:Activation Fn: relu #hidden_layers: 1 loss function: mean_absolute_error
# 0.921125517761189
# Results for hyperparameters:Activation Fn: relu #hidden_layers: 1 loss function: mean_absolute_percentage_error
# 0.9043131778027241
# Results for hyperparameters:Activation Fn: relu #hidden_layers: 1 loss function: <function huber_loss at 0x7f3a2b674a70>
# 0.922733444171953
# Results for hyperparameters:Activation Fn: relu #hidden_layers: 1 loss function: <function huber_loss_mean at 0x7f3a2b6748c0>
# 0.9292028818373665
# Updated hyperparameters for building: Goldwatermax_R2:0.9292028818373665: Activation Fn: relu #hidden_layers: 1 loss function: <function huber_loss_mean at 0x7f3a2b6748c0>
# Results for hyperparameters:Activation Fn: relu #hidden_layers: 3 loss function: mean_squared_error
# 0.9193388311147139
# Results for hyperparameters:Activation Fn: relu #hidden_layers: 3 loss function: mean_absolute_error
# 0.924240282259454
# Results for hyperparameters:Activation Fn: relu #hidden_layers: 3 loss function: mean_absolute_percentage_error
# 0.8994713563727829
# Results for hyperparameters:Activation Fn: relu #hidden_layers: 3 loss function: <function huber_loss at 0x7f3a2b674a70>
# 0.928768327599097
# Results for hyperparameters:Activation Fn: relu #hidden_layers: 3 loss function: <function huber_loss_mean at 0x7f3a2b6748c0>
# 0.9193679253394137
# Results for hyperparameters:Activation Fn: relu #hidden_layers: 5 loss function: mean_squared_error
# 0.9314155554909099
# Updated hyperparameters for building: Goldwatermax_R2:0.9314155554909099: Activation Fn: relu #hidden_layers: 5 loss function: mean_squared_error
# Results for hyperparameters:Activation Fn: relu #hidden_layers: 5 loss function: mean_absolute_error
# 0.9235152888668232
# Results for hyperparameters:Activation Fn: relu #hidden_layers: 5 loss function: mean_absolute_percentage_error
# 0.8917627537965535
# Results for hyperparameters:Activation Fn: relu #hidden_layers: 5 loss function: <function huber_loss at 0x7f3a2b674a70>
# 0.9237154856606851
# Results for hyperparameters:Activation Fn: relu #hidden_layers: 5 loss function: <function huber_loss_mean at 0x7f3a2b6748c0>
# 0.9193694459652572
# Results for hyperparameters:Activation Fn: elu #hidden_layers: 1 loss function: mean_squared_error
# 0.9285390470957883
# Results for hyperparameters:Activation Fn: elu #hidden_layers: 1 loss function: mean_absolute_error
# 0.9226940976508304
# Results for hyperparameters:Activation Fn: elu #hidden_layers: 1 loss function: mean_absolute_percentage_error
# 0.8224348822755555
# Results for hyperparameters:Activation Fn: elu #hidden_layers: 1 loss function: <function huber_loss at 0x7f3a2b674a70>
# 0.9275069926080436
# Results for hyperparameters:Activation Fn: elu #hidden_layers: 1 loss function: <function huber_loss_mean at 0x7f3a2b6748c0>
# 0.9311831208461976
# Results for hyperparameters:Activation Fn: elu #hidden_layers: 3 loss function: mean_squared_error
# 0.9297652694622696
# Results for hyperparameters:Activation Fn: elu #hidden_layers: 3 loss function: mean_absolute_error
# 0.9189218558714026
# Results for hyperparameters:Activation Fn: elu #hidden_layers: 3 loss function: mean_absolute_percentage_error
# 0.5121464525058204
# Results for hyperparameters:Activation Fn: elu #hidden_layers: 3 loss function: <function huber_loss at 0x7f3a2b674a70>
# 0.9284816234185431
# Results for hyperparameters:Activation Fn: elu #hidden_layers: 3 loss function: <function huber_loss_mean at 0x7f3a2b6748c0>
# 0.9291352230425935
# Results for hyperparameters:Activation Fn: elu #hidden_layers: 5 loss function: mean_squared_error
# 0.9301620879566812
# Results for hyperparameters:Activation Fn: elu #hidden_layers: 5 loss function: mean_absolute_error
# 0.9114819128215036
# Results for hyperparameters:Activation Fn: elu #hidden_layers: 5 loss function: mean_absolute_percentage_error
# 0.39067157785053375
# Results for hyperparameters:Activation Fn: elu #hidden_layers: 5 loss function: <function huber_loss at 0x7f3a2b674a70>
# 0.9256897339313106
# Results for hyperparameters:Activation Fn: elu #hidden_layers: 5 loss function: <function huber_loss_mean at 0x7f3a2b6748c0>
# 0.9252219731805054
# Results for hyperparameters:Activation Fn: selu #hidden_layers: 1 loss function: mean_squared_error
# 0.9274136816157681
# Results for hyperparameters:Activation Fn: selu #hidden_layers: 1 loss function: mean_absolute_error
# 0.9235849723482521
# Results for hyperparameters:Activation Fn: selu #hidden_layers: 1 loss function: mean_absolute_percentage_error
# 0.785134787101704
# Results for hyperparameters:Activation Fn: selu #hidden_layers: 1 loss function: <function huber_loss at 0x7f3a2b674a70>
# 0.9257522133262108
# Results for hyperparameters:Activation Fn: selu #hidden_layers: 1 loss function: <function huber_loss_mean at 0x7f3a2b6748c0>
# 0.9270860261421916
# Results for hyperparameters:Activation Fn: selu #hidden_layers: 3 loss function: mean_squared_error
# 0.9301002226717501
# Results for hyperparameters:Activation Fn: selu #hidden_layers: 3 loss function: mean_absolute_error
# 0.9210225672138076
# Results for hyperparameters:Activation Fn: selu #hidden_layers: 3 loss function: mean_absolute_percentage_error
# 0.8154636017054141
# Results for hyperparameters:Activation Fn: selu #hidden_layers: 3 loss function: <function huber_loss at 0x7f3a2b674a70>
# 0.9204513453798926
# Results for hyperparameters:Activation Fn: selu #hidden_layers: 3 loss function: <function huber_loss_mean at 0x7f3a2b6748c0>
# 0.9291354122840003
# Results for hyperparameters:Activation Fn: selu #hidden_layers: 5 loss function: mean_squared_error
# 0.926867556966218
# Results for hyperparameters:Activation Fn: selu #hidden_layers: 5 loss function: mean_absolute_error
# 0.9203741676489154
# Results for hyperparameters:Activation Fn: selu #hidden_layers: 5 loss function: mean_absolute_percentage_error
# 0.8823691583177704
# Results for hyperparameters:Activation Fn: selu #hidden_layers: 5 loss function: <function huber_loss at 0x7f3a2b674a70>
# 0.925009446099637
# Results for hyperparameters:Activation Fn: selu #hidden_layers: 5 loss function: <function huber_loss_mean at 0x7f3a2b6748c0>
# 0.9244044433705867
# Results for hyperparameters:Activation Fn: leaky_relu #hidden_layers: 1 loss function: mean_squared_error
# 0.9244183712640928
# Results for hyperparameters:Activation Fn: leaky_relu #hidden_layers: 1 loss function: mean_absolute_error
# 0.9245823307054454
# Results for hyperparameters:Activation Fn: leaky_relu #hidden_layers: 1 loss function: mean_absolute_percentage_error
# 0.8651603998352433
# Results for hyperparameters:Activation Fn: leaky_relu #hidden_layers: 1 loss function: <function huber_loss at 0x7f3a2b674a70>
# 0.9322956527989885
# Updated hyperparameters for building: Goldwatermax_R2:0.9322956527989885: Activation Fn: leaky_relu #hidden_layers: 1 loss function: <function huber_loss at 0x7f3a2b674a70>
# Results for hyperparameters:Activation Fn: leaky_relu #hidden_layers: 1 loss function: <function huber_loss_mean at 0x7f3a2b6748c0>
# 0.9236869729499064
# Results for hyperparameters:Activation Fn: leaky_relu #hidden_layers: 3 loss function: mean_squared_error
# 0.9267501182721918
# Results for hyperparameters:Activation Fn: leaky_relu #hidden_layers: 3 loss function: mean_absolute_error
# 0.9252922974112123
# Results for hyperparameters:Activation Fn: leaky_relu #hidden_layers: 3 loss function: mean_absolute_percentage_error
# 0.89607861735167
# Results for hyperparameters:Activation Fn: leaky_relu #hidden_layers: 3 loss function: <function huber_loss at 0x7f3a2b674a70>
# 0.9225218999355344
# Results for hyperparameters:Activation Fn: leaky_relu #hidden_layers: 3 loss function: <function huber_loss_mean at 0x7f3a2b6748c0>
# 0.9291411637388747
# Results for hyperparameters:Activation Fn: leaky_relu #hidden_layers: 5 loss function: mean_squared_error
# 0.9319977415870396
# Results for hyperparameters:Activation Fn: leaky_relu #hidden_layers: 5 loss function: mean_absolute_error
# 0.9241048854951864
# Results for hyperparameters:Activation Fn: leaky_relu #hidden_layers: 5 loss function: mean_absolute_percentage_error
# 0.9037744548928897
# Results for hyperparameters:Activation Fn: leaky_relu #hidden_layers: 5 loss function: <function huber_loss at 0x7f3a2b674a70>
# 0.9251742131003592
# Results for hyperparameters:Activation Fn: leaky_relu #hidden_layers: 5 loss function: <function huber_loss_mean at 0x7f3a2b6748c0>
# 0.9282294016765329
# Results for hyperparameters:Activation Fn: tanh #hidden_layers: 1 loss function: mean_squared_error
# 0.9265725774311373
# Results for hyperparameters:Activation Fn: tanh #hidden_layers: 1 loss function: mean_absolute_error
# 0.9192426067154033
# Results for hyperparameters:Activation Fn: tanh #hidden_layers: 1 loss function: mean_absolute_percentage_error
# 0.839834426150414
# Results for hyperparameters:Activation Fn: tanh #hidden_layers: 1 loss function: <function huber_loss at 0x7f3a2b674a70>
# 0.9271859932129568
# Results for hyperparameters:Activation Fn: tanh #hidden_layers: 1 loss function: <function huber_loss_mean at 0x7f3a2b6748c0>
# 0.9315684250460985
# Results for hyperparameters:Activation Fn: tanh #hidden_layers: 3 loss function: mean_squared_error
# 0.9306195212314863
# Results for hyperparameters:Activation Fn: tanh #hidden_layers: 3 loss function: mean_absolute_error
# 0.9151292143161264
# Results for hyperparameters:Activation Fn: tanh #hidden_layers: 3 loss function: mean_absolute_percentage_error
# 0.5573395921998296
# Results for hyperparameters:Activation Fn: tanh #hidden_layers: 3 loss function: <function huber_loss at 0x7f3a2b674a70>
# 0.9284149611826649
# Results for hyperparameters:Activation Fn: tanh #hidden_layers: 3 loss function: <function huber_loss_mean at 0x7f3a2b6748c0>
# 0.9206780613218387
# Results for hyperparameters:Activation Fn: tanh #hidden_layers: 5 loss function: mean_squared_error
# 0.9213199193313232
# Results for hyperparameters:Activation Fn: tanh #hidden_layers: 5 loss function: mean_absolute_error
# 0.9208890640931633
# Results for hyperparameters:Activation Fn: tanh #hidden_layers: 5 loss function: mean_absolute_percentage_error
# 0.7389032756017252
# Results for hyperparameters:Activation Fn: tanh #hidden_layers: 5 loss function: <function huber_loss at 0x7f3a2b674a70>
# 0.9200068815479308
# Results for hyperparameters:Activation Fn: tanh #hidden_layers: 5 loss function: <function huber_loss_mean at 0x7f3a2b6748c0>
# 0.9188112523311435
# Find parameters for Bulldog Hall
# Results for hyperparameters:Activation Fn: relu #hidden_layers: 1 loss function: mean_squared_error
# 0.4970880660721888
# Updated hyperparameters for building: Bulldog Hallmax_R2:0.4970880660721888: Activation Fn: relu #hidden_layers: 1 loss function: mean_squared_error
# Results for hyperparameters:Activation Fn: relu #hidden_layers: 1 loss function: mean_absolute_error
# 0.49140043268203915
# Results for hyperparameters:Activation Fn: relu #hidden_layers: 1 loss function: mean_absolute_percentage_error
# 0.29564699394834537
# Results for hyperparameters:Activation Fn: relu #hidden_layers: 1 loss function: <function huber_loss at 0x7f3a2b674a70>
# 0.5140447989251302
# Updated hyperparameters for building: Bulldog Hallmax_R2:0.5140447989251302: Activation Fn: relu #hidden_layers: 1 loss function: <function huber_loss at 0x7f3a2b674a70>
# Results for hyperparameters:Activation Fn: relu #hidden_layers: 1 loss function: <function huber_loss_mean at 0x7f3a2b6748c0>
# 0.52099129269994
# Updated hyperparameters for building: Bulldog Hallmax_R2:0.52099129269994: Activation Fn: relu #hidden_layers: 1 loss function: <function huber_loss_mean at 0x7f3a2b6748c0>
# Results for hyperparameters:Activation Fn: relu #hidden_layers: 3 loss function: mean_squared_error
# 0.5232632587318539
# Updated hyperparameters for building: Bulldog Hallmax_R2:0.5232632587318539: Activation Fn: relu #hidden_layers: 3 loss function: mean_squared_error
# Results for hyperparameters:Activation Fn: relu #hidden_layers: 3 loss function: mean_absolute_error
# 0.5058657231199905
# Results for hyperparameters:Activation Fn: relu #hidden_layers: 3 loss function: mean_absolute_percentage_error
# 0.2085664460139124
# Results for hyperparameters:Activation Fn: relu #hidden_layers: 3 loss function: <function huber_loss at 0x7f3a2b674a70>
# 0.5202419590546494
# Results for hyperparameters:Activation Fn: relu #hidden_layers: 3 loss function: <function huber_loss_mean at 0x7f3a2b6748c0>
# 0.5047202401327339
# Results for hyperparameters:Activation Fn: relu #hidden_layers: 5 loss function: mean_squared_error
# 0.5151143062542451
# Results for hyperparameters:Activation Fn: relu #hidden_layers: 5 loss function: mean_absolute_error
# 0.5008329273736911
# Results for hyperparameters:Activation Fn: relu #hidden_layers: 5 loss function: mean_absolute_percentage_error
# 0.26393294768857534
# Results for hyperparameters:Activation Fn: relu #hidden_layers: 5 loss function: <function huber_loss at 0x7f3a2b674a70>
# 0.5385142335606705
# Updated hyperparameters for building: Bulldog Hallmax_R2:0.5385142335606705: Activation Fn: relu #hidden_layers: 5 loss function: <function huber_loss at 0x7f3a2b674a70>
# Results for hyperparameters:Activation Fn: relu #hidden_layers: 5 loss function: <function huber_loss_mean at 0x7f3a2b6748c0>
# 0.4954883665936607
# Results for hyperparameters:Activation Fn: elu #hidden_layers: 1 loss function: mean_squared_error
# 0.48556628809018076
# Results for hyperparameters:Activation Fn: elu #hidden_layers: 1 loss function: mean_absolute_error
# 0.48550306031918367
# Results for hyperparameters:Activation Fn: elu #hidden_layers: 1 loss function: mean_absolute_percentage_error
# 0.3060199251732447
# Results for hyperparameters:Activation Fn: elu #hidden_layers: 1 loss function: <function huber_loss at 0x7f3a2b674a70>
# 0.5058151731173799
# Results for hyperparameters:Activation Fn: elu #hidden_layers: 1 loss function: <function huber_loss_mean at 0x7f3a2b6748c0>
# 0.5014615194446946
# Results for hyperparameters:Activation Fn: elu #hidden_layers: 3 loss function: mean_squared_error
# 0.5079475994738659
# Results for hyperparameters:Activation Fn: elu #hidden_layers: 3 loss function: mean_absolute_error
# 0.4973503067674473
# Results for hyperparameters:Activation Fn: elu #hidden_layers: 3 loss function: mean_absolute_percentage_error
# 0.21412354539801637
# Results for hyperparameters:Activation Fn: elu #hidden_layers: 3 loss function: <function huber_loss at 0x7f3a2b674a70>
# 0.5022428961003447
# Results for hyperparameters:Activation Fn: elu #hidden_layers: 3 loss function: <function huber_loss_mean at 0x7f3a2b6748c0>
# 0.5046033698189196
# Results for hyperparameters:Activation Fn: elu #hidden_layers: 5 loss function: mean_squared_error
# 0.5031317773539152
# Results for hyperparameters:Activation Fn: elu #hidden_layers: 5 loss function: mean_absolute_error
# 0.49732817747958136
# Results for hyperparameters:Activation Fn: elu #hidden_layers: 5 loss function: mean_absolute_percentage_error
# 0.30750857919841457
# Results for hyperparameters:Activation Fn: elu #hidden_layers: 5 loss function: <function huber_loss at 0x7f3a2b674a70>
# 0.5063190743584038
# Results for hyperparameters:Activation Fn: elu #hidden_layers: 5 loss function: <function huber_loss_mean at 0x7f3a2b6748c0>
# 0.5031576740858028
# Results for hyperparameters:Activation Fn: selu #hidden_layers: 1 loss function: mean_squared_error
# 0.5099040518940858
# Results for hyperparameters:Activation Fn: selu #hidden_layers: 1 loss function: mean_absolute_error
# 0.48908743710652425
# Results for hyperparameters:Activation Fn: selu #hidden_layers: 1 loss function: mean_absolute_percentage_error
# 0.31037298317693784
# Results for hyperparameters:Activation Fn: selu #hidden_layers: 1 loss function: <function huber_loss at 0x7f3a2b674a70>
# 0.5154408954676464
# Results for hyperparameters:Activation Fn: selu #hidden_layers: 1 loss function: <function huber_loss_mean at 0x7f3a2b6748c0>
# 0.5081011058324943
# Results for hyperparameters:Activation Fn: selu #hidden_layers: 3 loss function: mean_squared_error
# 0.5134155618929563
# Results for hyperparameters:Activation Fn: selu #hidden_layers: 3 loss function: mean_absolute_error
# 0.4932838590670994
# Results for hyperparameters:Activation Fn: selu #hidden_layers: 3 loss function: mean_absolute_percentage_error
# 0.2738984621057412
# Results for hyperparameters:Activation Fn: selu #hidden_layers: 3 loss function: <function huber_loss at 0x7f3a2b674a70>
# 0.5290134033045011
# Results for hyperparameters:Activation Fn: selu #hidden_layers: 3 loss function: <function huber_loss_mean at 0x7f3a2b6748c0>
# 0.49920169077950005
# Results for hyperparameters:Activation Fn: selu #hidden_layers: 5 loss function: mean_squared_error
# 0.5221857125531602
# Results for hyperparameters:Activation Fn: selu #hidden_layers: 5 loss function: mean_absolute_error
# 0.4871975385563415
# Results for hyperparameters:Activation Fn: selu #hidden_layers: 5 loss function: mean_absolute_percentage_error
# 0.2573745156139091
# Results for hyperparameters:Activation Fn: selu #hidden_layers: 5 loss function: <function huber_loss at 0x7f3a2b674a70>
# 0.509457544882914
# Results for hyperparameters:Activation Fn: selu #hidden_layers: 5 loss function: <function huber_loss_mean at 0x7f3a2b6748c0>
# 0.522931514540661
# Results for hyperparameters:Activation Fn: leaky_relu #hidden_layers: 1 loss function: mean_squared_error
# 0.4926680214410122
# Results for hyperparameters:Activation Fn: leaky_relu #hidden_layers: 1 loss function: mean_absolute_error
# 0.4855961037666018
# Results for hyperparameters:Activation Fn: leaky_relu #hidden_layers: 1 loss function: mean_absolute_percentage_error
# 0.22386856641912511
# Results for hyperparameters:Activation Fn: leaky_relu #hidden_layers: 1 loss function: <function huber_loss at 0x7f3a2b674a70>
# 0.5054759914225002
# Results for hyperparameters:Activation Fn: leaky_relu #hidden_layers: 1 loss function: <function huber_loss_mean at 0x7f3a2b6748c0>
# 0.49673128642188336
# Results for hyperparameters:Activation Fn: leaky_relu #hidden_layers: 3 loss function: mean_squared_error
# 0.5171840539679711
# Results for hyperparameters:Activation Fn: leaky_relu #hidden_layers: 3 loss function: mean_absolute_error
# 0.48657587627307686
# Results for hyperparameters:Activation Fn: leaky_relu #hidden_layers: 3 loss function: mean_absolute_percentage_error
# 0.2814421255758953
# Results for hyperparameters:Activation Fn: leaky_relu #hidden_layers: 3 loss function: <function huber_loss at 0x7f3a2b674a70>
# 0.5133594161522201
# Results for hyperparameters:Activation Fn: leaky_relu #hidden_layers: 3 loss function: <function huber_loss_mean at 0x7f3a2b6748c0>
# 0.5069875101751992
# Results for hyperparameters:Activation Fn: leaky_relu #hidden_layers: 5 loss function: mean_squared_error
# 0.5023391003459792
# Results for hyperparameters:Activation Fn: leaky_relu #hidden_layers: 5 loss function: mean_absolute_error
# 0.48372368658396103
# Results for hyperparameters:Activation Fn: leaky_relu #hidden_layers: 5 loss function: mean_absolute_percentage_error
# 0.2525824701007544
# Results for hyperparameters:Activation Fn: leaky_relu #hidden_layers: 5 loss function: <function huber_loss at 0x7f3a2b674a70>
# 0.5266928715329691
# Results for hyperparameters:Activation Fn: leaky_relu #hidden_layers: 5 loss function: <function huber_loss_mean at 0x7f3a2b6748c0>
# 0.5176079224724661
# Results for hyperparameters:Activation Fn: tanh #hidden_layers: 1 loss function: mean_squared_error
# 0.4914612135438118
# Results for hyperparameters:Activation Fn: tanh #hidden_layers: 1 loss function: mean_absolute_error
# 0.4946545629695642
# Results for hyperparameters:Activation Fn: tanh #hidden_layers: 1 loss function: mean_absolute_percentage_error
# 0.2557112881097511
# Results for hyperparameters:Activation Fn: tanh #hidden_layers: 1 loss function: <function huber_loss at 0x7f3a2b674a70>
# 0.5025464449199802
# Results for hyperparameters:Activation Fn: tanh #hidden_layers: 1 loss function: <function huber_loss_mean at 0x7f3a2b6748c0>
# 0.5067450073040307
# Results for hyperparameters:Activation Fn: tanh #hidden_layers: 3 loss function: mean_squared_error
# 0.5003126723328921
# Results for hyperparameters:Activation Fn: tanh #hidden_layers: 3 loss function: mean_absolute_error
# 0.4944420280683721
# Results for hyperparameters:Activation Fn: tanh #hidden_layers: 3 loss function: mean_absolute_percentage_error
# 0.30700468215417676
# Results for hyperparameters:Activation Fn: tanh #hidden_layers: 3 loss function: <function huber_loss at 0x7f3a2b674a70>
# 0.5103896789643365
# Results for hyperparameters:Activation Fn: tanh #hidden_layers: 3 loss function: <function huber_loss_mean at 0x7f3a2b6748c0>
# 0.5090890985074328
# Results for hyperparameters:Activation Fn: tanh #hidden_layers: 5 loss function: mean_squared_error
# 0.4954138489163721
# Results for hyperparameters:Activation Fn: tanh #hidden_layers: 5 loss function: mean_absolute_error
# 0.4856051545006784
# Results for hyperparameters:Activation Fn: tanh #hidden_layers: 5 loss function: mean_absolute_percentage_error
# 0.2626448383978195
# Results for hyperparameters:Activation Fn: tanh #hidden_layers: 5 loss function: <function huber_loss at 0x7f3a2b674a70>
# 0.5116623087761923
# Results for hyperparameters:Activation Fn: tanh #hidden_layers: 5 loss function: <function huber_loss_mean at 0x7f3a2b6748c0>
# 0.5070452720871874
# Find parameters for ISTB 2
# Results for hyperparameters:Activation Fn: relu #hidden_layers: 1 loss function: mean_squared_error
# 0.8685900787493636
# Updated hyperparameters for building: ISTB 2max_R2:0.8685900787493636: Activation Fn: relu #hidden_layers: 1 loss function: mean_squared_error
# Results for hyperparameters:Activation Fn: relu #hidden_layers: 1 loss function: mean_absolute_error
# 0.868446630762192
# Results for hyperparameters:Activation Fn: relu #hidden_layers: 1 loss function: mean_absolute_percentage_error
# 0.8620589523901754
# Results for hyperparameters:Activation Fn: relu #hidden_layers: 1 loss function: <function huber_loss at 0x7f3a2b674a70>
# 0.8658680764957053
# Results for hyperparameters:Activation Fn: relu #hidden_layers: 1 loss function: <function huber_loss_mean at 0x7f3a2b6748c0>
# 0.8643256431704402
# Results for hyperparameters:Activation Fn: relu #hidden_layers: 3 loss function: mean_squared_error
# 0.8728644638907911
# Updated hyperparameters for building: ISTB 2max_R2:0.8728644638907911: Activation Fn: relu #hidden_layers: 3 loss function: mean_squared_error
# Results for hyperparameters:Activation Fn: relu #hidden_layers: 3 loss function: mean_absolute_error
# 0.8691970837333086
# Results for hyperparameters:Activation Fn: relu #hidden_layers: 3 loss function: mean_absolute_percentage_error
# 0.8726335176615339
# Results for hyperparameters:Activation Fn: relu #hidden_layers: 3 loss function: <function huber_loss at 0x7f3a2b674a70>
# 0.8676421887739693
# Results for hyperparameters:Activation Fn: relu #hidden_layers: 3 loss function: <function huber_loss_mean at 0x7f3a2b6748c0>
# 0.8705934003831273
# Results for hyperparameters:Activation Fn: relu #hidden_layers: 5 loss function: mean_squared_error
# 0.8681892396901036
# Results for hyperparameters:Activation Fn: relu #hidden_layers: 5 loss function: mean_absolute_error
# 0.8727551796476993
# Results for hyperparameters:Activation Fn: relu #hidden_layers: 5 loss function: mean_absolute_percentage_error
# 0.8354206293758155
# Results for hyperparameters:Activation Fn: relu #hidden_layers: 5 loss function: <function huber_loss at 0x7f3a2b674a70>
# 0.8662494073575336
# Results for hyperparameters:Activation Fn: relu #hidden_layers: 5 loss function: <function huber_loss_mean at 0x7f3a2b6748c0>
# 0.8688819640322412
# Results for hyperparameters:Activation Fn: elu #hidden_layers: 1 loss function: mean_squared_error
# 0.867382077825677
# Results for hyperparameters:Activation Fn: elu #hidden_layers: 1 loss function: mean_absolute_error
# 0.8727377162363876
# Results for hyperparameters:Activation Fn: elu #hidden_layers: 1 loss function: mean_absolute_percentage_error
# 0.8382527285665837
# Results for hyperparameters:Activation Fn: elu #hidden_layers: 1 loss function: <function huber_loss at 0x7f3a2b674a70>
# 0.8653163077119161
# Results for hyperparameters:Activation Fn: elu #hidden_layers: 1 loss function: <function huber_loss_mean at 0x7f3a2b6748c0>
# 0.8702604218308241
# Results for hyperparameters:Activation Fn: elu #hidden_layers: 3 loss function: mean_squared_error
# 0.8741388705062698
# Updated hyperparameters for building: ISTB 2max_R2:0.8741388705062698: Activation Fn: elu #hidden_layers: 3 loss function: mean_squared_error
# Results for hyperparameters:Activation Fn: elu #hidden_layers: 3 loss function: mean_absolute_error
# 0.8682519174672906
# Results for hyperparameters:Activation Fn: elu #hidden_layers: 3 loss function: mean_absolute_percentage_error
# 0.8342949356532171
# Results for hyperparameters:Activation Fn: elu #hidden_layers: 3 loss function: <function huber_loss at 0x7f3a2b674a70>
# 0.870526025350639
# Results for hyperparameters:Activation Fn: elu #hidden_layers: 3 loss function: <function huber_loss_mean at 0x7f3a2b6748c0>
# 0.8623825828545344
# Results for hyperparameters:Activation Fn: elu #hidden_layers: 5 loss function: mean_squared_error
# 0.8708260817929724
# Results for hyperparameters:Activation Fn: elu #hidden_layers: 5 loss function: mean_absolute_error
# 0.874441164463276
# Updated hyperparameters for building: ISTB 2max_R2:0.874441164463276: Activation Fn: elu #hidden_layers: 5 loss function: mean_absolute_error
# Results for hyperparameters:Activation Fn: elu #hidden_layers: 5 loss function: mean_absolute_percentage_error
# 0.8623997853808455
# Results for hyperparameters:Activation Fn: elu #hidden_layers: 5 loss function: <function huber_loss at 0x7f3a2b674a70>
# 0.8681045910425057
# Results for hyperparameters:Activation Fn: elu #hidden_layers: 5 loss function: <function huber_loss_mean at 0x7f3a2b6748c0>
# 0.8709596127450231
# Results for hyperparameters:Activation Fn: selu #hidden_layers: 1 loss function: mean_squared_error
# 0.874925811862829
# Updated hyperparameters for building: ISTB 2max_R2:0.874925811862829: Activation Fn: selu #hidden_layers: 1 loss function: mean_squared_error
# Results for hyperparameters:Activation Fn: selu #hidden_layers: 1 loss function: mean_absolute_error
# 0.8750977789425747
# Updated hyperparameters for building: ISTB 2max_R2:0.8750977789425747: Activation Fn: selu #hidden_layers: 1 loss function: mean_absolute_error
# Results for hyperparameters:Activation Fn: selu #hidden_layers: 1 loss function: mean_absolute_percentage_error
# 0.8576555452376828
# Results for hyperparameters:Activation Fn: selu #hidden_layers: 1 loss function: <function huber_loss at 0x7f3a2b674a70>
# 0.8727348254552683
# Results for hyperparameters:Activation Fn: selu #hidden_layers: 1 loss function: <function huber_loss_mean at 0x7f3a2b6748c0>
# 0.8651101603373961
# Results for hyperparameters:Activation Fn: selu #hidden_layers: 3 loss function: mean_squared_error
# 0.8780701626631597
# Updated hyperparameters for building: ISTB 2max_R2:0.8780701626631597: Activation Fn: selu #hidden_layers: 3 loss function: mean_squared_error
# Results for hyperparameters:Activation Fn: selu #hidden_layers: 3 loss function: mean_absolute_error
# 0.860200016034274
# Results for hyperparameters:Activation Fn: selu #hidden_layers: 3 loss function: mean_absolute_percentage_error
# 0.8379712897458128
# Results for hyperparameters:Activation Fn: selu #hidden_layers: 3 loss function: <function huber_loss at 0x7f3a2b674a70>
# 0.8701421396935437
# Results for hyperparameters:Activation Fn: selu #hidden_layers: 3 loss function: <function huber_loss_mean at 0x7f3a2b6748c0>
# 0.8664032570883575
# Results for hyperparameters:Activation Fn: selu #hidden_layers: 5 loss function: mean_squared_error
# 0.8666365060981698
# Results for hyperparameters:Activation Fn: selu #hidden_layers: 5 loss function: mean_absolute_error
# 0.8630670711458741
# Results for hyperparameters:Activation Fn: selu #hidden_layers: 5 loss function: mean_absolute_percentage_error
# 0.8730302731321579
# Results for hyperparameters:Activation Fn: selu #hidden_layers: 5 loss function: <function huber_loss at 0x7f3a2b674a70>
# 0.8608191645945051
# Results for hyperparameters:Activation Fn: selu #hidden_layers: 5 loss function: <function huber_loss_mean at 0x7f3a2b6748c0>
# 0.8665789022241988
# Results for hyperparameters:Activation Fn: leaky_relu #hidden_layers: 1 loss function: mean_squared_error
# 0.8676459849192534
# Results for hyperparameters:Activation Fn: leaky_relu #hidden_layers: 1 loss function: mean_absolute_error
# 0.8725961257365473
# Results for hyperparameters:Activation Fn: leaky_relu #hidden_layers: 1 loss function: mean_absolute_percentage_error
# 0.8609948242148697
# Results for hyperparameters:Activation Fn: leaky_relu #hidden_layers: 1 loss function: <function huber_loss at 0x7f3a2b674a70>
# 0.8730290043978861
# Results for hyperparameters:Activation Fn: leaky_relu #hidden_layers: 1 loss function: <function huber_loss_mean at 0x7f3a2b6748c0>
# 0.8652817557073013
# Results for hyperparameters:Activation Fn: leaky_relu #hidden_layers: 3 loss function: mean_squared_error
# 0.8602907160234068
# Results for hyperparameters:Activation Fn: leaky_relu #hidden_layers: 3 loss function: mean_absolute_error
# 0.8618163424702369
# Results for hyperparameters:Activation Fn: leaky_relu #hidden_layers: 3 loss function: mean_absolute_percentage_error
# 0.8318243043689547
# Results for hyperparameters:Activation Fn: leaky_relu #hidden_layers: 3 loss function: <function huber_loss at 0x7f3a2b674a70>
# 0.8630836844792352
# Results for hyperparameters:Activation Fn: leaky_relu #hidden_layers: 3 loss function: <function huber_loss_mean at 0x7f3a2b6748c0>
# 0.8585910217155535
# Results for hyperparameters:Activation Fn: leaky_relu #hidden_layers: 5 loss function: mean_squared_error
# 0.8635459484632991
# Results for hyperparameters:Activation Fn: leaky_relu #hidden_layers: 5 loss function: mean_absolute_error
# 0.8743195483807986
# Results for hyperparameters:Activation Fn: leaky_relu #hidden_layers: 5 loss function: mean_absolute_percentage_error
# 0.8334276161374433
# Results for hyperparameters:Activation Fn: leaky_relu #hidden_layers: 5 loss function: <function huber_loss at 0x7f3a2b674a70>
# 0.8646783983824232
# Results for hyperparameters:Activation Fn: leaky_relu #hidden_layers: 5 loss function: <function huber_loss_mean at 0x7f3a2b6748c0>
# 0.8606062209137495
# Results for hyperparameters:Activation Fn: tanh #hidden_layers: 1 loss function: mean_squared_error
# 0.8666764145275248
# Results for hyperparameters:Activation Fn: tanh #hidden_layers: 1 loss function: mean_absolute_error
# 0.8636140034687196
# Results for hyperparameters:Activation Fn: tanh #hidden_layers: 1 loss function: mean_absolute_percentage_error
# 0.8513575228484241
# Results for hyperparameters:Activation Fn: tanh #hidden_layers: 1 loss function: <function huber_loss at 0x7f3a2b674a70>
# 0.8590196506350086
# Results for hyperparameters:Activation Fn: tanh #hidden_layers: 1 loss function: <function huber_loss_mean at 0x7f3a2b6748c0>
# 0.8709054791555028
# Results for hyperparameters:Activation Fn: tanh #hidden_layers: 3 loss function: mean_squared_error
# 0.8646567703972756
# Results for hyperparameters:Activation Fn: tanh #hidden_layers: 3 loss function: mean_absolute_error
# 0.8724442522347714
# Results for hyperparameters:Activation Fn: tanh #hidden_layers: 3 loss function: mean_absolute_percentage_error
# 0.86374489864829
# Results for hyperparameters:Activation Fn: tanh #hidden_layers: 3 loss function: <function huber_loss at 0x7f3a2b674a70>
# 0.8664939106256909
# Results for hyperparameters:Activation Fn: tanh #hidden_layers: 3 loss function: <function huber_loss_mean at 0x7f3a2b6748c0>
# 0.8706227948112192
# Results for hyperparameters:Activation Fn: tanh #hidden_layers: 5 loss function: mean_squared_error
# 0.8635837399861493
# Results for hyperparameters:Activation Fn: tanh #hidden_layers: 5 loss function: mean_absolute_error
# 0.8743318094234317
# Results for hyperparameters:Activation Fn: tanh #hidden_layers: 5 loss function: mean_absolute_percentage_error
# 0.8614160467802565
# Results for hyperparameters:Activation Fn: tanh #hidden_layers: 5 loss function: <function huber_loss at 0x7f3a2b674a70>
# 0.8657753481841709
# Results for hyperparameters:Activation Fn: tanh #hidden_layers: 5 loss function: <function huber_loss_mean at 0x7f3a2b6748c0>
# 0.860515561792334
# Find parameters for Psychology North
# Results for hyperparameters:Activation Fn: relu #hidden_layers: 1 loss function: mean_squared_error
# 0.7350331519935875
# Updated hyperparameters for building: Psychology Northmax_R2:0.7350331519935875: Activation Fn: relu #hidden_layers: 1 loss function: mean_squared_error
# Results for hyperparameters:Activation Fn: relu #hidden_layers: 1 loss function: mean_absolute_error
# 0.7114626812543428
# Results for hyperparameters:Activation Fn: relu #hidden_layers: 1 loss function: mean_absolute_percentage_error
# 0.527343458933776
# Results for hyperparameters:Activation Fn: relu #hidden_layers: 1 loss function: <function huber_loss at 0x7f3a2b674a70>
# 0.7148563100413499
# Results for hyperparameters:Activation Fn: relu #hidden_layers: 1 loss function: <function huber_loss_mean at 0x7f3a2b6748c0>
# 0.7104060042959863
# Results for hyperparameters:Activation Fn: relu #hidden_layers: 3 loss function: mean_squared_error
# 0.7167274731407092
# Results for hyperparameters:Activation Fn: relu #hidden_layers: 3 loss function: mean_absolute_error
# 0.7028317722710463
# Results for hyperparameters:Activation Fn: relu #hidden_layers: 3 loss function: mean_absolute_percentage_error
# 0.5330510413091533
# Results for hyperparameters:Activation Fn: relu #hidden_layers: 3 loss function: <function huber_loss at 0x7f3a2b674a70>
# 0.7209992099825027
# Results for hyperparameters:Activation Fn: relu #hidden_layers: 3 loss function: <function huber_loss_mean at 0x7f3a2b6748c0>
# 0.713427008077571
# Results for hyperparameters:Activation Fn: relu #hidden_layers: 5 loss function: mean_squared_error
# 0.6933813112467677
# Results for hyperparameters:Activation Fn: relu #hidden_layers: 5 loss function: mean_absolute_error
# 0.7036813809182381
# Results for hyperparameters:Activation Fn: relu #hidden_layers: 5 loss function: mean_absolute_percentage_error
# 0.48029486508557995
# Results for hyperparameters:Activation Fn: relu #hidden_layers: 5 loss function: <function huber_loss at 0x7f3a2b674a70>
# 0.711627625055959
# Results for hyperparameters:Activation Fn: relu #hidden_layers: 5 loss function: <function huber_loss_mean at 0x7f3a2b6748c0>
# 0.7080136467580687
# Results for hyperparameters:Activation Fn: elu #hidden_layers: 1 loss function: mean_squared_error
# 0.7340258990622228
# Results for hyperparameters:Activation Fn: elu #hidden_layers: 1 loss function: mean_absolute_error
# 0.7367654999003315
# Updated hyperparameters for building: Psychology Northmax_R2:0.7367654999003315: Activation Fn: elu #hidden_layers: 1 loss function: mean_absolute_error
# Results for hyperparameters:Activation Fn: elu #hidden_layers: 1 loss function: mean_absolute_percentage_error
# 0.2368668260775293
# Results for hyperparameters:Activation Fn: elu #hidden_layers: 1 loss function: <function huber_loss at 0x7f3a2b674a70>
# 0.7257267324168047
# Results for hyperparameters:Activation Fn: elu #hidden_layers: 1 loss function: <function huber_loss_mean at 0x7f3a2b6748c0>
# 0.720559484292187
# Results for hyperparameters:Activation Fn: elu #hidden_layers: 3 loss function: mean_squared_error
# 0.7172849853119554
# Results for hyperparameters:Activation Fn: elu #hidden_layers: 3 loss function: mean_absolute_error
# 0.7147790491533355
# Results for hyperparameters:Activation Fn: elu #hidden_layers: 3 loss function: mean_absolute_percentage_error
# 0.4123440279106587
# Results for hyperparameters:Activation Fn: elu #hidden_layers: 3 loss function: <function huber_loss at 0x7f3a2b674a70>
# 0.724022867284388
# Results for hyperparameters:Activation Fn: elu #hidden_layers: 3 loss function: <function huber_loss_mean at 0x7f3a2b6748c0>
# 0.7190090795045474
# Results for hyperparameters:Activation Fn: elu #hidden_layers: 5 loss function: mean_squared_error
# 0.7024489009256611
# Results for hyperparameters:Activation Fn: elu #hidden_layers: 5 loss function: mean_absolute_error
# 0.7020443176388007
# Results for hyperparameters:Activation Fn: elu #hidden_layers: 5 loss function: mean_absolute_percentage_error
# 0.4683957103230636
# Results for hyperparameters:Activation Fn: elu #hidden_layers: 5 loss function: <function huber_loss at 0x7f3a2b674a70>
# 0.7046684713174807
# Results for hyperparameters:Activation Fn: elu #hidden_layers: 5 loss function: <function huber_loss_mean at 0x7f3a2b6748c0>
# 0.709605960660324
# Results for hyperparameters:Activation Fn: selu #hidden_layers: 1 loss function: mean_squared_error
# 0.722951141196001
# Results for hyperparameters:Activation Fn: selu #hidden_layers: 1 loss function: mean_absolute_error
# 0.724874261817025
# Results for hyperparameters:Activation Fn: selu #hidden_layers: 1 loss function: mean_absolute_percentage_error
# 0.38923834919335076
# Results for hyperparameters:Activation Fn: selu #hidden_layers: 1 loss function: <function huber_loss at 0x7f3a2b674a70>
# 0.7126317991964086
# Results for hyperparameters:Activation Fn: selu #hidden_layers: 1 loss function: <function huber_loss_mean at 0x7f3a2b6748c0>
# 0.7084716213619711
# Results for hyperparameters:Activation Fn: selu #hidden_layers: 3 loss function: mean_squared_error
# 0.7062614262835165
# Results for hyperparameters:Activation Fn: selu #hidden_layers: 3 loss function: mean_absolute_error
# 0.717269128851852
# Results for hyperparameters:Activation Fn: selu #hidden_layers: 3 loss function: mean_absolute_percentage_error
# 0.40343266201759
# Results for hyperparameters:Activation Fn: selu #hidden_layers: 3 loss function: <function huber_loss at 0x7f3a2b674a70>
# 0.704973626750196
# Results for hyperparameters:Activation Fn: selu #hidden_layers: 3 loss function: <function huber_loss_mean at 0x7f3a2b6748c0>
# 0.7061546868093531
# Results for hyperparameters:Activation Fn: selu #hidden_layers: 5 loss function: mean_squared_error
# 0.7174495255162303
# Results for hyperparameters:Activation Fn: selu #hidden_layers: 5 loss function: mean_absolute_error
# 0.7105893211157562
# Results for hyperparameters:Activation Fn: selu #hidden_layers: 5 loss function: mean_absolute_percentage_error
# 0.45744194298154917
# Results for hyperparameters:Activation Fn: selu #hidden_layers: 5 loss function: <function huber_loss at 0x7f3a2b674a70>
# 0.7073558968252895
# Results for hyperparameters:Activation Fn: selu #hidden_layers: 5 loss function: <function huber_loss_mean at 0x7f3a2b6748c0>
# 0.7250824120185912
# Results for hyperparameters:Activation Fn: leaky_relu #hidden_layers: 1 loss function: mean_squared_error
# 0.7341236342451978
# Results for hyperparameters:Activation Fn: leaky_relu #hidden_layers: 1 loss function: mean_absolute_error
# 0.735805615724633
# Results for hyperparameters:Activation Fn: leaky_relu #hidden_layers: 1 loss function: mean_absolute_percentage_error
# 0.3557648190651159
# Results for hyperparameters:Activation Fn: leaky_relu #hidden_layers: 1 loss function: <function huber_loss at 0x7f3a2b674a70>
# 0.7271372283220412
# Results for hyperparameters:Activation Fn: leaky_relu #hidden_layers: 1 loss function: <function huber_loss_mean at 0x7f3a2b6748c0>
# 0.7220171888523923
# Results for hyperparameters:Activation Fn: leaky_relu #hidden_layers: 3 loss function: mean_squared_error
# 0.7148604085382518
# Results for hyperparameters:Activation Fn: leaky_relu #hidden_layers: 3 loss function: mean_absolute_error
# 0.6718127516521075
# Results for hyperparameters:Activation Fn: leaky_relu #hidden_layers: 3 loss function: mean_absolute_percentage_error
# 0.3703963941828238
# Results for hyperparameters:Activation Fn: leaky_relu #hidden_layers: 3 loss function: <function huber_loss at 0x7f3a2b674a70>
# 0.7208076752440901
# Results for hyperparameters:Activation Fn: leaky_relu #hidden_layers: 3 loss function: <function huber_loss_mean at 0x7f3a2b6748c0>
# 0.7084604680014064
# Results for hyperparameters:Activation Fn: leaky_relu #hidden_layers: 5 loss function: mean_squared_error
# 0.7163470721069358
# Results for hyperparameters:Activation Fn: leaky_relu #hidden_layers: 5 loss function: mean_absolute_error
# 0.7116870913906816
# Results for hyperparameters:Activation Fn: leaky_relu #hidden_layers: 5 loss function: mean_absolute_percentage_error
# 0.45108022966138794
# Results for hyperparameters:Activation Fn: leaky_relu #hidden_layers: 5 loss function: <function huber_loss at 0x7f3a2b674a70>
# 0.7038889918515223
# Results for hyperparameters:Activation Fn: leaky_relu #hidden_layers: 5 loss function: <function huber_loss_mean at 0x7f3a2b6748c0>
# 0.7007117965634446
# Results for hyperparameters:Activation Fn: tanh #hidden_layers: 1 loss function: mean_squared_error
# 0.7108069297181661
# Results for hyperparameters:Activation Fn: tanh #hidden_layers: 1 loss function: mean_absolute_error
# 0.706009745273959
# Results for hyperparameters:Activation Fn: tanh #hidden_layers: 1 loss function: mean_absolute_percentage_error
# 0.3761453755006362
# Results for hyperparameters:Activation Fn: tanh #hidden_layers: 1 loss function: <function huber_loss at 0x7f3a2b674a70>
# 0.7053734699243386
# Results for hyperparameters:Activation Fn: tanh #hidden_layers: 1 loss function: <function huber_loss_mean at 0x7f3a2b6748c0>
# 0.72396180727149
# Results for hyperparameters:Activation Fn: tanh #hidden_layers: 3 loss function: mean_squared_error
# 0.7169747548023355
# Results for hyperparameters:Activation Fn: tanh #hidden_layers: 3 loss function: mean_absolute_error
# 0.7143346542233346
# Results for hyperparameters:Activation Fn: tanh #hidden_layers: 3 loss function: mean_absolute_percentage_error
# 0.36566339147686444
# Results for hyperparameters:Activation Fn: tanh #hidden_layers: 3 loss function: <function huber_loss at 0x7f3a2b674a70>
# 0.7229748102900286
# Results for hyperparameters:Activation Fn: tanh #hidden_layers: 3 loss function: <function huber_loss_mean at 0x7f3a2b6748c0>
# 0.722796759171128
# Results for hyperparameters:Activation Fn: tanh #hidden_layers: 5 loss function: mean_squared_error
# 0.7138188442698888
# Results for hyperparameters:Activation Fn: tanh #hidden_layers: 5 loss function: mean_absolute_error
# 0.6948011584434637
# Results for hyperparameters:Activation Fn: tanh #hidden_layers: 5 loss function: mean_absolute_percentage_error
# 0.2283763380911803
# Results for hyperparameters:Activation Fn: tanh #hidden_layers: 5 loss function: <function huber_loss at 0x7f3a2b674a70>
# 0.7005890386185878
# Results for hyperparameters:Activation Fn: tanh #hidden_layers: 5 loss function: <function huber_loss_mean at 0x7f3a2b6748c0>
# 0.7014283292853438
# Find parameters for Schwada COB
# Results for hyperparameters:Activation Fn: relu #hidden_layers: 1 loss function: mean_squared_error
# 0.8438524257543452
# Updated hyperparameters for building: Schwada COBmax_R2:0.8438524257543452: Activation Fn: relu #hidden_layers: 1 loss function: mean_squared_error
# Results for hyperparameters:Activation Fn: relu #hidden_layers: 1 loss function: mean_absolute_error
# 0.8370555415391587
# Results for hyperparameters:Activation Fn: relu #hidden_layers: 1 loss function: mean_absolute_percentage_error
# 0.7398120120195923
# Results for hyperparameters:Activation Fn: relu #hidden_layers: 1 loss function: <function huber_loss at 0x7f3a2b674a70>
# 0.8416111731109244
# Results for hyperparameters:Activation Fn: relu #hidden_layers: 1 loss function: <function huber_loss_mean at 0x7f3a2b6748c0>
# 0.8373475848722447
# Results for hyperparameters:Activation Fn: relu #hidden_layers: 3 loss function: mean_squared_error
# 0.837845209004501
# Results for hyperparameters:Activation Fn: relu #hidden_layers: 3 loss function: mean_absolute_error
# 0.8500242869927436
# ...
# 0.54822047139139
# Results for hyperparameters:Activation Fn: leaky_relu #hidden_layers: 3 loss function: mean_absolute_error
# 0.5399811218407385
# Results for hyperparameters:Activation Fn: leaky_relu #hidden_layers: 3 loss function: mean_absolute_percentage_error
# 0.4084796309615354
# Results for hyperparameters:Activation Fn: leaky_relu #hidden_layers: 3 loss function: <function huber_loss at 0x7f3a2b674a70>
# 0.5408515170389023
# Results for hyperparameters:Activation Fn: leaky_relu #hidden_layers: 3 loss function: <function huber_loss_mean at 0x7f3a2b6748c0>
# 0.5413749410521302
# Results for hyperparameters:Activation Fn: leaky_relu #hidden_layers: 5 loss function: mean_squared_error
# 0.5447222419405249
# Results for hyperparameters:Activation Fn: leaky_relu #hidden_layers: 5 loss function: mean_absolute_error
# 0.5674539227458236
# Results for hyperparameters:Activation Fn: leaky_relu #hidden_layers: 5 loss function: mean_absolute_percentage_error
# 0.43203648528683136
# Results for hyperparameters:Activation Fn: leaky_relu #hidden_layers: 5 loss function: <function huber_loss at 0x7f3a2b674a70>
# 0.518356205268288
# Results for hyperparameters:Activation Fn: leaky_relu #hidden_layers: 5 loss function: <function huber_loss_mean at 0x7f3a2b6748c0>
# 0.5266051871622107
# Results for hyperparameters:Activation Fn: tanh #hidden_layers: 1 loss function: mean_squared_error
# 0.5450893686148408
# Results for hyperparameters:Activation Fn: tanh #hidden_layers: 1 loss function: mean_absolute_error
# 0.5542926623721669
# Results for hyperparameters:Activation Fn: tanh #hidden_layers: 1 loss function: mean_absolute_percentage_error
# 0.1949074115532432
# Results for hyperparameters:Activation Fn: tanh #hidden_layers: 1 loss function: <function huber_loss at 0x7f3a2b674a70>
# 0.5407081480533525
# Results for hyperparameters:Activation Fn: tanh #hidden_layers: 1 loss function: <function huber_loss_mean at 0x7f3a2b6748c0>
# 0.528501857764955
# Results for hyperparameters:Activation Fn: tanh #hidden_layers: 3 loss function: mean_squared_error
# 0.5426521211987955
# Results for hyperparameters:Activation Fn: tanh #hidden_layers: 3 loss function: mean_absolute_error
# 0.5639558042425425
# Results for hyperparameters:Activation Fn: tanh #hidden_layers: 3 loss function: mean_absolute_percentage_error
# 0.00567574979904828
# Results for hyperparameters:Activation Fn: tanh #hidden_layers: 3 loss function: <function huber_loss at 0x7f3a2b674a70>
# 0.5334623370439915
# Results for hyperparameters:Activation Fn: tanh #hidden_layers: 3 loss function: <function huber_loss_mean at 0x7f3a2b6748c0>
# 0.546931951800291
# Results for hyperparameters:Activation Fn: tanh #hidden_layers: 5 loss function: mean_squared_error
# 0.5267408626344657
# Results for hyperparameters:Activation Fn: tanh #hidden_layers: 5 loss function: mean_absolute_error
# 0.5625193043210004
# Results for hyperparameters:Activation Fn: tanh #hidden_layers: 5 loss function: mean_absolute_percentage_error
# 0.415426558042977
# Results for hyperparameters:Activation Fn: tanh #hidden_layers: 5 loss function: <function huber_loss at 0x7f3a2b674a70>
# 0.556846719375166
# Results for hyperparameters:Activation Fn: tanh #hidden_layers: 5 loss function: <function huber_loss_mean at 0x7f3a2b6748c0>
# 0.5294870920508027
# Find parameters for ISTB 4
# Results for hyperparameters:Activation Fn: relu #hidden_layers: 1 loss function: mean_squared_error
# 0.9020765762533253
# Updated hyperparameters for building: ISTB 4max_R2:0.9020765762533253: Activation Fn: relu #hidden_layers: 1 loss function: mean_squared_error
# Results for hyperparameters:Activation Fn: relu #hidden_layers: 1 loss function: mean_absolute_error
# 0.9091639109773129
# Updated hyperparameters for building: ISTB 4max_R2:0.9091639109773129: Activation Fn: relu #hidden_layers: 1 loss function: mean_absolute_error
# Results for hyperparameters:Activation Fn: relu #hidden_layers: 1 loss function: mean_absolute_percentage_error
# 0.88829019526038
# Results for hyperparameters:Activation Fn: relu #hidden_layers: 1 loss function: <function huber_loss at 0x7f3a2b674a70>
# 0.9069154445476104
# Results for hyperparameters:Activation Fn: relu #hidden_layers: 1 loss function: <function huber_loss_mean at 0x7f3a2b6748c0>
# 0.904349833418202
# Results for hyperparameters:Activation Fn: relu #hidden_layers: 3 loss function: mean_squared_error
# 0.9050629142646879
# Results for hyperparameters:Activation Fn: relu #hidden_layers: 3 loss function: mean_absolute_error
# 0.8980784942777824
# Results for hyperparameters:Activation Fn: relu #hidden_layers: 3 loss function: mean_absolute_percentage_error
# 0.894699924053247
# Results for hyperparameters:Activation Fn: relu #hidden_layers: 3 loss function: <function huber_loss at 0x7f3a2b674a70>
# 0.9008709383617938
# Results for hyperparameters:Activation Fn: relu #hidden_layers: 3 loss function: <function huber_loss_mean at 0x7f3a2b6748c0>
# 0.901638149556856
# Results for hyperparameters:Activation Fn: relu #hidden_layers: 5 loss function: mean_squared_error
# 0.9032543512838228
# Results for hyperparameters:Activation Fn: relu #hidden_layers: 5 loss function: mean_absolute_error
# 0.9001280997565783
# Results for hyperparameters:Activation Fn: relu #hidden_layers: 5 loss function: mean_absolute_percentage_error
# 0.8976918479854659
# Results for hyperparameters:Activation Fn: relu #hidden_layers: 5 loss function: <function huber_loss at 0x7f3a2b674a70>
# 0.899330988290578
# Results for hyperparameters:Activation Fn: relu #hidden_layers: 5 loss function: <function huber_loss_mean at 0x7f3a2b6748c0>
# 0.9067609595793513
# Results for hyperparameters:Activation Fn: elu #hidden_layers: 1 loss function: mean_squared_error
# 0.9032512546243567
# Results for hyperparameters:Activation Fn: elu #hidden_layers: 1 loss function: mean_absolute_error
# 0.9113318451820657
# Updated hyperparameters for building: ISTB 4max_R2:0.9113318451820657: Activation Fn: elu #hidden_layers: 1 loss function: mean_absolute_error
# Results for hyperparameters:Activation Fn: elu #hidden_layers: 1 loss function: mean_absolute_percentage_error
# 0.8012484374658482
# Results for hyperparameters:Activation Fn: elu #hidden_layers: 1 loss function: <function huber_loss at 0x7f3a2b674a70>
# 0.9142933548515622
# Updated hyperparameters for building: ISTB 4max_R2:0.9142933548515622: Activation Fn: elu #hidden_layers: 1 loss function: <function huber_loss at 0x7f3a2b674a70>
# Results for hyperparameters:Activation Fn: elu #hidden_layers: 1 loss function: <function huber_loss_mean at 0x7f3a2b6748c0>
# 0.9073894542649187
# Results for hyperparameters:Activation Fn: elu #hidden_layers: 3 loss function: mean_squared_error
# 0.9017996164096745
# Results for hyperparameters:Activation Fn: elu #hidden_layers: 3 loss function: mean_absolute_error
# 0.9028933675666737
# Results for hyperparameters:Activation Fn: elu #hidden_layers: 3 loss function: mean_absolute_percentage_error
# 0.6453813206038597
# Results for hyperparameters:Activation Fn: elu #hidden_layers: 3 loss function: <function huber_loss at 0x7f3a2b674a70>
# 0.9145170912564872
# Updated hyperparameters for building: ISTB 4max_R2:0.9145170912564872: Activation Fn: elu #hidden_layers: 3 loss function: <function huber_loss at 0x7f3a2b674a70>
# Results for hyperparameters:Activation Fn: elu #hidden_layers: 3 loss function: <function huber_loss_mean at 0x7f3a2b6748c0>
# 0.9107119335390589
# Results for hyperparameters:Activation Fn: elu #hidden_layers: 5 loss function: mean_squared_error
# 0.905763704969745
# Results for hyperparameters:Activation Fn: elu #hidden_layers: 5 loss function: mean_absolute_error
# 0.9108920683035816
# Results for hyperparameters:Activation Fn: elu #hidden_layers: 5 loss function: mean_absolute_percentage_error
# -0.004781291964164103
# Results for hyperparameters:Activation Fn: elu #hidden_layers: 5 loss function: <function huber_loss at 0x7f3a2b674a70>
# 0.9069598725021715
# Results for hyperparameters:Activation Fn: elu #hidden_layers: 5 loss function: <function huber_loss_mean at 0x7f3a2b6748c0>
# 0.9043061235444197
# Results for hyperparameters:Activation Fn: selu #hidden_layers: 1 loss function: mean_squared_error
# 0.9065057120963567
# Results for hyperparameters:Activation Fn: selu #hidden_layers: 1 loss function: mean_absolute_error
# 0.9029472753658948
# Results for hyperparameters:Activation Fn: selu #hidden_layers: 1 loss function: mean_absolute_percentage_error
# 0.6152537092003916
# Results for hyperparameters:Activation Fn: selu #hidden_layers: 1 loss function: <function huber_loss at 0x7f3a2b674a70>
# 0.8993313668048969
# Results for hyperparameters:Activation Fn: selu #hidden_layers: 1 loss function: <function huber_loss_mean at 0x7f3a2b6748c0>
# 0.9044635014658035
# Results for hyperparameters:Activation Fn: selu #hidden_layers: 3 loss function: mean_squared_error
# 0.8912661927595008
# Results for hyperparameters:Activation Fn: selu #hidden_layers: 3 loss function: mean_absolute_error
# 0.9142645248257509
# Results for hyperparameters:Activation Fn: selu #hidden_layers: 3 loss function: mean_absolute_percentage_error
# 0.24323047010974297
# Results for hyperparameters:Activation Fn: selu #hidden_layers: 3 loss function: <function huber_loss at 0x7f3a2b674a70>
# 0.9015607674641269
# Results for hyperparameters:Activation Fn: selu #hidden_layers: 3 loss function: <function huber_loss_mean at 0x7f3a2b6748c0>
# 0.8976491375858842
# Results for hyperparameters:Activation Fn: selu #hidden_layers: 5 loss function: mean_squared_error
# 0.903013493009395
# Results for hyperparameters:Activation Fn: selu #hidden_layers: 5 loss function: mean_absolute_error
# 0.9083051676104983
# Results for hyperparameters:Activation Fn: selu #hidden_layers: 5 loss function: mean_absolute_percentage_error
# -0.10063354264247848
# Results for hyperparameters:Activation Fn: selu #hidden_layers: 5 loss function: <function huber_loss at 0x7f3a2b674a70>
# 0.9064735262434633
# Results for hyperparameters:Activation Fn: selu #hidden_layers: 5 loss function: <function huber_loss_mean at 0x7f3a2b6748c0>
# 0.9045523612030022
# Results for hyperparameters:Activation Fn: leaky_relu #hidden_layers: 1 loss function: mean_squared_error
# 0.9068078458473856
# Results for hyperparameters:Activation Fn: leaky_relu #hidden_layers: 1 loss function: mean_absolute_error
# 0.9116135069969877
# Results for hyperparameters:Activation Fn: leaky_relu #hidden_layers: 1 loss function: mean_absolute_percentage_error
# 0.7778187484500264
# Results for hyperparameters:Activation Fn: leaky_relu #hidden_layers: 1 loss function: <function huber_loss at 0x7f3a2b674a70>
# 0.8991839925226196
# Results for hyperparameters:Activation Fn: leaky_relu #hidden_layers: 1 loss function: <function huber_loss_mean at 0x7f3a2b6748c0>
# 0.904887238267206
# Results for hyperparameters:Activation Fn: leaky_relu #hidden_layers: 3 loss function: mean_squared_error
# 0.9003628611724791
# Results for hyperparameters:Activation Fn: leaky_relu #hidden_layers: 3 loss function: mean_absolute_error
# 0.9100360949738009
# Results for hyperparameters:Activation Fn: leaky_relu #hidden_layers: 3 loss function: mean_absolute_percentage_error
# 0.8446661720825209
# Results for hyperparameters:Activation Fn: leaky_relu #hidden_layers: 3 loss function: <function huber_loss at 0x7f3a2b674a70>
# 0.9029209062346004
# Results for hyperparameters:Activation Fn: leaky_relu #hidden_layers: 3 loss function: <function huber_loss_mean at 0x7f3a2b6748c0>
# 0.9125517149791257
# Results for hyperparameters:Activation Fn: leaky_relu #hidden_layers: 5 loss function: mean_squared_error
# 0.9028744420510516
# Results for hyperparameters:Activation Fn: leaky_relu #hidden_layers: 5 loss function: mean_absolute_error
# 0.9075183524884483
# Results for hyperparameters:Activation Fn: leaky_relu #hidden_layers: 5 loss function: mean_absolute_percentage_error
# 0.8843863397302486
# Results for hyperparameters:Activation Fn: leaky_relu #hidden_layers: 5 loss function: <function huber_loss at 0x7f3a2b674a70>
# 0.9046969495197561
# Results for hyperparameters:Activation Fn: leaky_relu #hidden_layers: 5 loss function: <function huber_loss_mean at 0x7f3a2b6748c0>
# 0.9072953451319136
# Results for hyperparameters:Activation Fn: tanh #hidden_layers: 1 loss function: mean_squared_error
# 0.9057455746054454
# Results for hyperparameters:Activation Fn: tanh #hidden_layers: 1 loss function: mean_absolute_error
# 0.9007411412535026
# Results for hyperparameters:Activation Fn: tanh #hidden_layers: 1 loss function: mean_absolute_percentage_error
# 0.5031347559527312
# Results for hyperparameters:Activation Fn: tanh #hidden_layers: 1 loss function: <function huber_loss at 0x7f3a2b674a70>
# 0.9046627655245734
# Results for hyperparameters:Activation Fn: tanh #hidden_layers: 1 loss function: <function huber_loss_mean at 0x7f3a2b6748c0>
# 0.9015712344928357
# Results for hyperparameters:Activation Fn: tanh #hidden_layers: 3 loss function: mean_squared_error
# 0.9018297987934529
# Results for hyperparameters:Activation Fn: tanh #hidden_layers: 3 loss function: mean_absolute_error
# 0.9002978428897742
# Results for hyperparameters:Activation Fn: tanh #hidden_layers: 3 loss function: mean_absolute_percentage_error
# 0.2831476547285574
# Results for hyperparameters:Activation Fn: tanh #hidden_layers: 3 loss function: <function huber_loss at 0x7f3a2b674a70>
# 0.9013915421483135
# Results for hyperparameters:Activation Fn: tanh #hidden_layers: 3 loss function: <function huber_loss_mean at 0x7f3a2b6748c0>
# 0.9080484060445992
# Results for hyperparameters:Activation Fn: tanh #hidden_layers: 5 loss function: mean_squared_error
# 0.8990929713860765
# Results for hyperparameters:Activation Fn: tanh #hidden_layers: 5 loss function: mean_absolute_error
# 0.9068534608152606
# Results for hyperparameters:Activation Fn: tanh #hidden_layers: 5 loss function: mean_absolute_percentage_error
# -0.001027863948211749
# Results for hyperparameters:Activation Fn: tanh #hidden_layers: 5 loss function: <function huber_loss at 0x7f3a2b674a70>
# 0.9035333273533703
# Results for hyperparameters:Activation Fn: tanh #hidden_layers: 5 loss function: <function huber_loss_mean at 0x7f3a2b6748c0>
# 0.9056729650639794
#             bldgname R2_score_bigdata_best R2_score_limiteddata_best  \
# 0          Goldwater              0.941358                  0.932296
# 1       Bulldog Hall              0.822471                  0.538514
# 2             ISTB 2              0.940712                   0.87807
# 3   Psychology North              0.831601                  0.736765
# 4        Schwada COB              0.859398                  0.850024
# 5        Biodesign C              0.713277                  0.669637
# 6        Biodesign A              0.932901                  0.798969
# 7         Psychology              0.906009                  0.816637
# 8        Biodesign B              0.962345                  0.908075
# 9      Noble Library              0.783527                  0.577902
# 10            ISTB 4              0.974562                  0.914517
#
#    Activation Function No of hidden layers  \
# 0           leaky_relu                   1
# 1                 relu                   5
# 2                 selu                   3
# 3                  elu                   1
# 4                 relu                   3
# 5                 relu                   5
# 6           leaky_relu                   1
# 7                 selu                   5
# 8           leaky_relu                   1
# 9                  elu                   1
# 10                 elu                   3
#
#                                    Loss function
# 0        <function huber_loss at 0x7f3a2b674a70>
# 1        <function huber_loss at 0x7f3a2b674a70>
# 2                             mean_squared_error
# 3                            mean_absolute_error
# 4                            mean_absolute_error
# 5                            mean_absolute_error
# 6        <function huber_loss at 0x7f3a2b674a70>
# 7        <function huber_loss at 0x7f3a2b674a70>
# 8   <function huber_loss_mean at 0x7f3a2b6748c0>
# 9                            mean_absolute_error
# 10       <function huber_loss at 0x7f3a2b674a70>

# %%
optimal_model_buildings.to_csv('./optimal_models.csv', index=False)

# %%
optimal_models = pd.read_csv('./optimal_models.csv')
display(optimal_models)
# Out:
#             bldgname  R2_score_bigdata_best  R2_score_limiteddata_best  \
# 0          Goldwater               0.941358                   0.932296
# 1       Bulldog Hall               0.822471                   0.538514
# 2             ISTB 2               0.940712                   0.878070
# 3   Psychology North               0.831601                   0.736765
# 4        Schwada COB               0.859398                   0.850024
# 5        Biodesign C               0.713277                   0.669637
# 6        Biodesign A               0.932901                   0.798969
# 7         Psychology               0.906009                   0.816637
# 8        Biodesign B               0.962345                   0.908075
# 9      Noble Library               0.783527                   0.577902
# 10            ISTB 4               0.974562                   0.914517
#
#    Activation Function  No of hidden layers  \
# 0           leaky_relu                    1
# 1                 relu                    5
# 2                 selu                    3
# 3                  elu                    1
# 4                 relu                    3
# 5                 relu                    5
# 6           leaky_relu                    1
# 7                 selu                    5
# 8           leaky_relu                    1
# 9                  elu                    1
# 10                 elu                    3
#
#                                    Loss function
# 0        <function huber_loss at 0x7f3a2b674a70>
# 1        <function huber_loss at 0x7f3a2b674a70>
# 2                             mean_squared_error
# 3                            mean_absolute_error
# 4                            mean_absolute_error
# 5                            mean_absolute_error
# 6        <function huber_loss at 0x7f3a2b674a70>
# 7        <function huber_loss at 0x7f3a2b674a70>
# 8   <function huber_loss_mean at 0x7f3a2b6748c0>
# 9                            mean_absolute_error
# 10       <function huber_loss at 0x7f3a2b674a70>

# %% [markdown]
# ## 5.4 Train Model with Optimized hyperparameters

# %%
base_model = define_model('relu',5,'mae')
history = base_model.fit(X_train, Y_train, batch_size=128, epochs=100, verbose=0, validation_split=0.2)
# Out:
# mae
# Model: "sequential_68"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_306 (Dense)            (None, 10)                30
# _________________________________________________________________
# dense_307 (Dense)            (None, 8)                 88
# _________________________________________________________________
# dense_308 (Dense)            (None, 8)                 72
# _________________________________________________________________
# dense_309 (Dense)            (None, 8)                 72
# _________________________________________________________________
# dense_310 (Dense)            (None, 12)                108
# _________________________________________________________________
# dense_311 (Dense)            (None, 1)                 13
# =================================================================
# Total params: 383
# Trainable params: 383
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ## 5.5 Evaluate Base Model with Big Dataset and Limited Dataset

# %%
plot_curve(history)
RMSE, R2 = evaluate(base_model, X_test, Y_test)
RMSE_base_model, R2_base_model = evaluate(base_model, X_limited_test,Y_limited_test)
print(R2)
print(R2_base_model)
# Out:
# 0.9744392032899065
# 0.9225195443826308

# %% [markdown]
# ## 5.6 Transfer features and Fine Tune Base Model on Limited Dataset

# %%
fine_tuned_model = fine_tune(base_model,huber_loss)
# X_limited,Y_limited = prepare_data(envimet)
history = fine_tuned_model.fit(X_limited_train,Y_limited_train, epochs=100, verbose=0)

# %% [markdown]
# ## 5.7 Evaluate Fine-tuned Model on Limited Dataset

# %%
RMSE_fine_tune ,R2_fine_tune= evaluate(fine_tuned_model,X_limited_test,Y_limited_test)
print(R2_fine_tune)
# Out:
# 0.9655515485952206

# %% [markdown]
# ## 5.8 Implement for all Buildings and report score

# %%
from IPython.display import display
def model_multiple():
    ### Create dataframe and add building names ###
    rf_bld_scores = pd.DataFrame(columns = {"bldgname", "R2_score_base_model","RMSE_score_base_model", "R2_score_finetuned_model","RMSE_score_finetuned_model"})
    for i in range(len(Bldg_Lim)):
        rf_bld_scores = rf_bld_scores.append({'bldgname': Bldg_Lim[i]['bldgname'].unique()[0]}, ignore_index=True)
    rf_bld_scores.fillna(5)
    ### Append scores to all buildings ###
    for i in range(len(Bldg_Lim)):
        # drop na values if in dataframe
        if (Bldg_Lim[i].isnull().values.any() == True):
            Bldg_Lim[i] = Bldg_Lim[i].dropna()
        building_name = Bldg_Lim[i]['bldgname'][0] 
        print("Train model for "+ building_name )
        # Limited Data
        X_limited,Y_limited = prepare_data(Bldg_Lim[i])
        X_limited_train, X_limited_test, Y_limited_train,Y_limited_test = train_test_split(X_limited,Y_limited , test_size=0.1, random_state=20)
        #Big Data
        X,Y = prepare_data(Bldg_Big[i])
        X_train, X_test, Y_train,Y_test = train_test_split(X, Y, test_size=0.2, random_state=20)
        #read optimal model parameters for this building and train base_model using those parameters
        activation_function = optimal_models["Activation Function"][i]
        number_hl = optimal_models["No of hidden layers"][i]
        loss_function = optimal_models["Loss function"][i]
        if loss_function == '<function huber_loss at 0x7f3a2b674a70>':
            loss_function = huber_loss
        if loss_function == '<function huber_loss_mean at 0x7f3a2b6748c0>':
            loss_function = huber_loss_mean        
        base_model = define_model(activation_function,number_hl, loss_function)
        print("Train model for "+ building_name +" Big Data" )
        history_base = base_model.fit(X_train, Y_train, batch_size=128, epochs=100, verbose=0, validation_split=0.2)
        RMSE, R2 = evaluate(base_model, X_test, Y_test)
        RMSE_base_model, R2_base_model = evaluate(base_model, X_limited_test,Y_limited_test)
        rf_bld_scores["R2_score_base_model"][i] = R2_base_model
        rf_bld_scores["RMSE_score_base_model"][i] = RMSE_base_model   
        fine_tuned_model = fine_tune(base_model,loss_function)
        print("Train model for "+ building_name +" Limited Data" )
        history_fine_tune = fine_tuned_model.fit(X_limited_train,Y_limited_train, epochs=100, verbose=0)
        RMSE_fine_tune ,R2_fine_tune= evaluate(fine_tuned_model,X_limited_test,Y_limited_test)
        rf_bld_scores["R2_score_finetuned_model"][i] = R2_fine_tune
        rf_bld_scores["RMSE_score_finetuned_model"][i] = RMSE_fine_tune
        rf_bld_scores= rf_bld_scores[["bldgname", "R2_score_base_model","RMSE_score_base_model", "R2_score_finetuned_model","RMSE_score_finetuned_model"]]
    return rf_bld_scores
multiple_bldg_scores = model_multiple()
display(multiple_bldg_scores)
# Out:
# Train model for Goldwater
# Train model for Goldwater Big Data
# Train model for Goldwater Limited Data
# Train model for Bulldog Hall
# Train model for Bulldog Hall Big Data
# Train model for Bulldog Hall Limited Data
# Train model for ISTB 2
# Train model for ISTB 2 Big Data
# Train model for ISTB 2 Limited Data
# Train model for Psychology North
# Train model for Psychology North Big Data
# Train model for Psychology North Limited Data
# Train model for Schwada COB
# Train model for Schwada COB Big Data
# Train model for Schwada COB Limited Data
# Train model for Biodesign C
# Train model for Biodesign C Big Data
# Train model for Biodesign C Limited Data
# Train model for Biodesign A
# Train model for Biodesign A Big Data
# Train model for Biodesign A Limited Data
# Train model for Psychology
# Train model for Psychology Big Data
# Train model for Psychology Limited Data
# Train model for Biodesign B
# Train model for Biodesign B Big Data
# Train model for Biodesign B Limited Data
# Train model for Noble Library
# Train model for Noble Library Big Data
# Train model for Noble Library Limited Data
# Train model for ISTB 4
# Train model for ISTB 4 Big Data
# Train model for ISTB 4 Limited Data
#             bldgname R2_score_base_model RMSE_score_base_model  \
# 0          Goldwater            0.930507              0.274276
# 1       Bulldog Hall            0.514101              0.713965
# 2             ISTB 2            0.863653              0.382229
# 3   Psychology North            0.729198              0.514561
# 4        Schwada COB            0.837046              0.431821
# 5        Biodesign C            0.604872              0.637422
# 6        Biodesign A            0.798426              0.451535
# 7         Psychology            0.793316              0.444059
# 8        Biodesign B            0.901453              0.325471
# 9      Noble Library            0.554611              0.692392
# 10            ISTB 4            0.901588              0.298567
#
#    R2_score_finetuned_model RMSE_score_finetuned_model
# 0                  0.954688                   0.221475
# 1                  0.597257                   0.650007
# 2                  0.920404                   0.292044
# 3                  0.769289                   0.474947
# 4                   0.90565                    0.32858
# 5                  0.839342                   0.406452
# 6                   0.83611                   0.407146
# 7                   0.90526                   0.300645
# 8                  0.948448                   0.235403
# 9                  0.679277                   0.587553
# 10                 0.940699                   0.231765

# %% [markdown]
# <!-- Which buildings are we training for? To be decided depending on results  -->
# <!-- Train for all buildings automatically and report the scores for base_model and fine_tuned_model. -->
# <!-- What scores is RF reporting? RF reports the R2 score. Add R2 score to evaluators. Create a list for evaluating and then visualise it. Not a great score, needs improvements.  -->
# <!-- How to visualise the results? Made comparison matrix for now -->
# <!-- How to improve the results? Experiment with loss function -->
# <!-- Automate model selection: run over iterations of activation function, number of hidden layers, loss function  -->
# lr scheduler
# Change Y to y everywhere(Regression problem)
# Add functionality to pass building names which we want to model
